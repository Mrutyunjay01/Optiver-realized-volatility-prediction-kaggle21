# %%
from IPython.core.display import display, HTML

import os
import gc
import numpy as np
import numpy.matlib
import pandas as pd

from joblib import Parallel, delayed

from sklearn.cluster import KMeans
from sklearn import preprocessing, model_selection
from sklearn.preprocessing import MinMaxScaler, QuantileTransformer

import lightgbm as lgb


def set_seed(seed=69):
    np.random.seed(seed)
    pass

set_seed()

import warnings
warnings.filterwarnings('ignore')
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
target_name = 'target'
scores_folds = {}

# %%
def read_train_test():
    train = pd.read_csv('../input/optiver-realized-volatility-prediction/train.csv')
    test = pd.read_csv('../input/optiver-realized-volatility-prediction/test.csv')

    train['row_id'] = train['stock_id'].astype(str) + '-' + train['time_id'].astype(str)
    test['row_id'] = test['stock_id'].astype(str) + '-' + test['time_id'].astype(str)
    print(f'Our training set has {train.shape[0]} rows')
    
    return train, test

# %%
# data directory
data_dir = '../input/optiver-realized-volatility-prediction/'

def calc_wap1(df):
    # Function to calculate first WAP
    wap = (df['bid_price1'] * df['ask_size1'] + df['ask_price1'] * df['bid_size1']) / (df['bid_size1'] + df['ask_size1'])
    return wap

def calc_wap2(df):
    # Function to calculate second WAP
    wap = (df['bid_price2'] * df['ask_size2'] + df['ask_price2'] * df['bid_size2']) / (df['bid_size2'] + df['ask_size2'])
    return wap

def log_return(series):
    # Function to calculate the log of the return
    return np.log(series).diff()

def realized_volatility(series):
    # Calculate the realized volatility
    return np.sqrt(np.sum(series**2))

def count_unique(series):
    # Function to count unique elements of a series
    return len(np.unique(series))

def book_preprocessor(file_path):
    # Function to preprocess book data (for each stock id)
    
    df = pd.read_parquet(file_path)
    
    # Calculate Wap
    df['wap1'] = calc_wap1(df)
    df['wap2'] = calc_wap2(df)
    
    # Calculate log returns
    df['log_return1'] = df.groupby(['time_id'])['wap1'].apply(log_return)
    df['log_return2'] = df.groupby(['time_id'])['wap2'].apply(log_return)
    
    # Calculate wap balance
    df['wap_balance'] = abs(df['wap1'] - df['wap2'])
    
    # Calculate spread
    df['price_spread'] = (df['ask_price1'] - df['bid_price1']) / ((df['ask_price1'] + df['bid_price1']) / 2)
    df['price_spread2'] = (df['ask_price2'] - df['bid_price2']) / ((df['ask_price2'] + df['bid_price2']) / 2)
    df['bid_spread'] = df['bid_price1'] - df['bid_price2']
    df['ask_spread'] = df['ask_price1'] - df['ask_price2']
    df["bid_ask_spread"] = abs(df['bid_spread'] - df['ask_spread'])
    df['total_volume'] = (df['ask_size1'] + df['ask_size2']) + (df['bid_size1'] + df['bid_size2'])
    df['volume_imbalance'] = abs((df['ask_size1'] + df['ask_size2']) - (df['bid_size1'] + df['bid_size2']))
    
    # Dict for aggregations
    create_feature_dict = {
        'wap1': [np.sum, np.mean, np.std],
        'wap2': [np.sum, np.mean, np.std],
        'log_return1': [np.sum, realized_volatility, np.mean, np.std],
        'log_return2': [np.sum, realized_volatility, np.mean, np.std],
        'wap_balance': [np.sum, np.mean, np.std],
        'price_spread':[np.sum, np.mean, np.std],
        'price_spread2':[np.sum, np.mean, np.std],
        'bid_spread':[np.sum, np.mean, np.std],
        'ask_spread':[np.sum, np.mean, np.std],
        'total_volume':[np.sum, np.mean, np.std],
        'volume_imbalance':[np.sum, np.mean, np.std],
        "bid_ask_spread":[np.sum, np.mean, np.std],
    }
    
    def get_stats_window(seconds_in_bucket, add_suffix = False):
        # Function to get group stats for different windows (seconds in bucket)
        
        # Group by the window
        df_feature = df[df['seconds_in_bucket'] >= seconds_in_bucket].groupby(['time_id']).agg(create_feature_dict).reset_index()
        
        # Rename columns joining suffix
        df_feature.columns = ['_'.join(col) for col in df_feature.columns]
        
        # Add a suffix to differentiate windows
        if add_suffix:
            df_feature = df_feature.add_suffix('_' + str(seconds_in_bucket))
        return df_feature
    
    # Get the stats for different windows
    df_feature = get_stats_window(seconds_in_bucket = 0, add_suffix = False)
    df_feature_450 = get_stats_window(seconds_in_bucket = 450, add_suffix = True)
    df_feature_300 = get_stats_window(seconds_in_bucket = 300, add_suffix = True)
    df_feature_150 = get_stats_window(seconds_in_bucket = 150, add_suffix = True)
    
    # Merge all
    df_feature = df_feature.merge(df_feature_450, how = 'left', left_on = 'time_id_', right_on = 'time_id__450')
    df_feature = df_feature.merge(df_feature_300, how = 'left', left_on = 'time_id_', right_on = 'time_id__300')
    df_feature = df_feature.merge(df_feature_150, how = 'left', left_on = 'time_id_', right_on = 'time_id__150')

    # Drop unnecesary time_ids
    df_feature.drop(['time_id__450', 'time_id__300', 'time_id__150'], axis = 1, inplace = True)
    
    
    # Create row_id so we can merge
    stock_id = file_path.split('=')[1]
    df_feature['row_id'] = df_feature['time_id_'].apply(lambda x: f'{stock_id}-{x}')
    df_feature.drop(['time_id_'], axis = 1, inplace = True)
    
    return df_feature


def trade_preprocessor(file_path):
    # Function to preprocess trade data (for each stock id)
    
    df = pd.read_parquet(file_path)
    df['log_return'] = df.groupby('time_id')['price'].apply(log_return)
    
    # Dict for aggregations
    create_feature_dict = {
        'log_return':[realized_volatility],
        'seconds_in_bucket':[count_unique],
        'size':[np.sum, realized_volatility, np.mean, np.std, np.max, np.min],
        'order_count':[np.mean, np.sum, np.max],
    }
    
    def get_stats_window(seconds_in_bucket, add_suffix = False):
        # Function to get group stats for different windows (seconds in bucket)
        
        # Group by the window
        df_feature = df[df['seconds_in_bucket'] >= seconds_in_bucket].groupby(['time_id']).agg(create_feature_dict).reset_index()
        
        # Rename columns joining suffix
        df_feature.columns = ['_'.join(col) for col in df_feature.columns]
        
        # Add a suffix to differentiate windows
        if add_suffix:
            df_feature = df_feature.add_suffix('_' + str(seconds_in_bucket))
        return df_feature
    
    # Get the stats for different windows
    df_feature = get_stats_window(seconds_in_bucket = 0, add_suffix = False)
    df_feature_450 = get_stats_window(seconds_in_bucket = 450, add_suffix = True)
    df_feature_300 = get_stats_window(seconds_in_bucket = 300, add_suffix = True)
    df_feature_150 = get_stats_window(seconds_in_bucket = 150, add_suffix = True)
    
    def tendency(price, vol):    
        df_diff = np.diff(price)
        val = (df_diff/price[1:])*100
        power = np.sum(val*vol[1:])
        return(power)
    
    lis = []
    for n_time_id in df['time_id'].unique():
        df_id = df[df['time_id'] == n_time_id]        
        tendencyV = tendency(df_id['price'].values, df_id['size'].values)      
        f_max = np.sum(df_id['price'].values > np.mean(df_id['price'].values))
        f_min = np.sum(df_id['price'].values < np.mean(df_id['price'].values))
        df_max =  np.sum(np.diff(df_id['price'].values) > 0)
        df_min =  np.sum(np.diff(df_id['price'].values) < 0)
        abs_diff = np.median(np.abs( df_id['price'].values - np.mean(df_id['price'].values)))        
        energy = np.mean(df_id['price'].values**2)
        iqr_p = np.percentile(df_id['price'].values,75) - np.percentile(df_id['price'].values,25)
        abs_diff_v = np.median(np.abs( df_id['size'].values - np.mean(df_id['size'].values)))        
        energy_v = np.sum(df_id['size'].values**2)
        iqr_p_v = np.percentile(df_id['size'].values,75) - np.percentile(df_id['size'].values,25)
        
        lis.append({'time_id':n_time_id,'tendency':tendencyV,'f_max':f_max,'f_min':f_min,'df_max':df_max,'df_min':df_min,
                   'abs_diff':abs_diff,'energy':energy,'iqr_p':iqr_p,'abs_diff_v':abs_diff_v,'energy_v':energy_v,'iqr_p_v':iqr_p_v})
    
    df_lr = pd.DataFrame(lis)
        
   
    df_feature = df_feature.merge(df_lr, how = 'left', left_on = 'time_id_', right_on = 'time_id')
    
    # Merge all
    df_feature = df_feature.merge(df_feature_450, how = 'left', left_on = 'time_id_', right_on = 'time_id__450')
    df_feature = df_feature.merge(df_feature_300, how = 'left', left_on = 'time_id_', right_on = 'time_id__300')
    df_feature = df_feature.merge(df_feature_150, how = 'left', left_on = 'time_id_', right_on = 'time_id__150')

    # Drop unnecesary time_ids
    df_feature.drop(['time_id__450', 'time_id__300', 'time_id__150','time_id'], axis = 1, inplace = True)
    df_feature = df_feature.add_prefix('trade_')
    stock_id = file_path.split('=')[1]
    df_feature['row_id'] = df_feature['trade_time_id_'].apply(lambda x:f'{stock_id}-{x}')
    df_feature.drop(['trade_time_id_'], axis = 1, inplace = True)
    
    return df_feature


def get_time_stock(df):
    # Function to get group stats for the stock_id and time_id
    
    # Get realized volatility columns
    vol_cols = ['log_return1_realized_volatility', 'log_return2_realized_volatility', 'log_return1_realized_volatility_450', 'log_return2_realized_volatility_450', 
                'log_return1_realized_volatility_300', 'log_return2_realized_volatility_300', 'log_return1_realized_volatility_150', 'log_return2_realized_volatility_150', 
                'trade_log_return_realized_volatility', 'trade_log_return_realized_volatility_450', 'trade_log_return_realized_volatility_300', 'trade_log_return_realized_volatility_150']

    # Group by the stock id
    df_stock_id = df.groupby(['stock_id'])[vol_cols].agg(['mean', 'std', 'max', 'min']).reset_index()
    
    # Rename columns joining suffix
    df_stock_id.columns = ['_'.join(col) for col in df_stock_id.columns]
    df_stock_id = df_stock_id.add_suffix('_' + 'stock')

    # Group by the stock id
    df_time_id = df.groupby(['time_id'])[vol_cols].agg(['mean', 'std', 'max', 'min']).reset_index()
    
    # Rename columns joining suffix
    df_time_id.columns = ['_'.join(col) for col in df_time_id.columns]
    df_time_id = df_time_id.add_suffix('_' + 'time')
    
    # Merge with original dataframe
    df = df.merge(df_stock_id, how = 'left', left_on = ['stock_id'], right_on = ['stock_id__stock'])
    df = df.merge(df_time_id, how = 'left', left_on = ['time_id'], right_on = ['time_id__time'])
    df.drop(['stock_id__stock', 'time_id__time'], axis = 1, inplace = True)
    
    return df
    
    
def preprocessor(list_stock_ids, is_train = True):
    # Funtion to make preprocessing function in parallel (for each stock id)
    
    # Parrallel for loop
    def for_joblib(stock_id):
        # Train
        if is_train:
            file_path_book = data_dir + "book_train.parquet/stock_id=" + str(stock_id)
            file_path_trade = data_dir + "trade_train.parquet/stock_id=" + str(stock_id)
        # Test
        else:
            file_path_book = data_dir + "book_test.parquet/stock_id=" + str(stock_id)
            file_path_trade = data_dir + "trade_test.parquet/stock_id=" + str(stock_id)
    
        # Preprocess book and trade data and merge them
        df_tmp = pd.merge(book_preprocessor(file_path_book), trade_preprocessor(file_path_trade), on = 'row_id', how = 'left')
        
        # Return the merge dataframe
        return df_tmp
    
    # Use parallel api to call paralle for loop
    df = Parallel(n_jobs = -1, verbose = 1)(delayed(for_joblib)(stock_id) for stock_id in list_stock_ids)
    
    # Concatenate all the dataframes that return from Parallel
    df = pd.concat(df, ignore_index = True)
    
    return df


def rmspe(y_true, y_pred):
    # Function to calculate the root mean squared percentage error
    return np.sqrt(np.mean(np.square((y_true - y_pred) / y_true)))

def feval_rmspe(y_pred, lgb_train):
    # Function to early stop with root mean squared percentage error
    y_true = lgb_train.get_label()
    return 'RMSPE', rmspe(y_true, y_pred), False

# %%
# Read train and test
train, test = read_train_test()

# Get unique stock ids 
train_stock_ids = train['stock_id'].unique()

# Preprocess them using Parallel and our single stock id functions
train_ = preprocessor(train_stock_ids, is_train = True)
train = train.merge(train_, on = ['row_id'], how = 'left')

# Get unique stock ids 
test_stock_ids = test['stock_id'].unique()

# Preprocess them using Parallel and our single stock id functions
test_ = preprocessor(test_stock_ids, is_train = False)
test = test.merge(test_, on = ['row_id'], how = 'left')

# Get group stats of time_id and stock_id
train = get_time_stock(train)
test = get_time_stock(test)
# Out:
# Our training set has 428932 rows
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=-1)]: Done 112 out of 112 | elapsed: 27.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.3s finished

# %%
# replace by order sum (tau)
train['size_tau'] = np.sqrt(1/train['trade_seconds_in_bucket_count_unique'])
test['size_tau'] = np.sqrt(1/test['trade_seconds_in_bucket_count_unique'])
train['size_tau_450'] = np.sqrt(1/train['trade_seconds_in_bucket_count_unique_450'])
test['size_tau_450'] = np.sqrt(1/test['trade_seconds_in_bucket_count_unique_450'])
train['size_tau_300'] = np.sqrt(1/train['trade_seconds_in_bucket_count_unique_300'])
test['size_tau_300'] = np.sqrt(1/test['trade_seconds_in_bucket_count_unique_300'])
train['size_tau_150'] = np.sqrt(1/train['trade_seconds_in_bucket_count_unique_150'])
test['size_tau_150'] = np.sqrt(1/test['trade_seconds_in_bucket_count_unique_150'])

# tau2 
train['size_tau2'] = np.sqrt(1/train['trade_order_count_sum'])
test['size_tau2'] = np.sqrt(1/test['trade_order_count_sum'])
train['size_tau2_450'] = np.sqrt(0.25/train['trade_order_count_sum'])
test['size_tau2_450'] = np.sqrt(0.25/test['trade_order_count_sum'])
train['size_tau2_300'] = np.sqrt(0.5/train['trade_order_count_sum'])
test['size_tau2_300'] = np.sqrt(0.5/test['trade_order_count_sum'])
train['size_tau2_150'] = np.sqrt(0.75/train['trade_order_count_sum'])
test['size_tau2_150'] = np.sqrt(0.75/test['trade_order_count_sum'])

# delta tau
train['size_tau2_d'] = train['size_tau2_450'] - train['size_tau2']
test['size_tau2_d'] = test['size_tau2_450'] - test['size_tau2']

# %%
## kfold based on the knn++ algorithm
out_train = pd.read_csv('../input/optiver-realized-volatility-prediction/train.csv')
out_train = out_train.pivot(index='time_id', columns='stock_id', values='target')

# out_train[out_train.isna().any(axis=1)]
out_train = out_train.fillna(out_train.mean())
out_train.head()

# Code to add the just the read data after first execution
# Data separation based on knn ++
nfolds = 5 # number of folds
index = []
totDist = []
values = []

# Generates a matriz with the values of 
mat = out_train.values
scaler = MinMaxScaler(feature_range=(-1, 1))
mat = scaler.fit_transform(mat)
nind = int(mat.shape[0]/nfolds) # number of individuals

# Adds index in the last column
mat = np.c_[mat, np.arange(mat.shape[0])]
lineNumber = np.random.choice(np.array(mat.shape[0]), size=nfolds, replace=False)
lineNumber = np.sort(lineNumber)[::-1]
for n in range(nfolds):
    totDist.append(np.zeros(mat.shape[0] - nfolds))

# Saves index
for n in range(nfolds):    
    values.append([lineNumber[n]])

s = []
for n in range(nfolds):
    s.append(mat[lineNumber[n], :])
    mat = np.delete(mat, obj=lineNumber[n], axis=0)

for n in range(nind-1):    
    luck = np.random.uniform(0, 1, nfolds)
    
    for cycle in range(nfolds):
        # Saves the values of index           
        s[cycle] = np.matlib.repmat(s[cycle], mat.shape[0], 1)
        sumDist = np.sum((mat[:,:-1] - s[cycle][:, :-1])**2, axis=1)   
        totDist[cycle] += sumDist        
                
        # Probabilities
        f = totDist[cycle]/np.sum(totDist[cycle]) # normalizing the totDist
        j = 0
        kn = 0
        for val in f:
            j += val        
            if (j > luck[cycle]): # the column was selected
                break
            kn += 1
        lineNumber[cycle] = kn
        
        # Delete line of the value added    
        for n_iter in range(nfolds):
            totDist[n_iter] = np.delete(totDist[n_iter], obj=lineNumber[cycle], axis=0)
            j = 0
        
        s[cycle] = mat[lineNumber[cycle], :]
        values[cycle].append(int(mat[lineNumber[cycle], -1]))
        mat = np.delete(mat, obj=lineNumber[cycle], axis=0)

for n_mod in range(nfolds):
    values[n_mod] = out_train.index[values[n_mod]]

# %%
colNames = list(train)
colNames.remove('time_id')
colNames.remove('target')
colNames.remove('row_id')
colNames.remove('stock_id')

# %%
train.replace([np.inf, -np.inf], np.nan,inplace=True)
test.replace([np.inf, -np.inf], np.nan,inplace=True)
qt_train = []

for col in colNames:
    qt = QuantileTransformer(random_state=69, n_quantiles=2000, output_distribution='normal')
    train[col] = qt.fit_transform(train[[col]])
    test[col] = qt.transform(test[[col]])    
    qt_train.append(qt)

# %%
# Making agg features

train_p = pd.read_csv('../input/optiver-realized-volatility-prediction/train.csv')
train_p = train_p.pivot(index='time_id', columns='stock_id', values='target')
corr = train_p.corr()
ids = corr.index
kmeans = KMeans(n_clusters=7, random_state=0).fit(corr.values)

l = []
for n in range(7):
    l.append ([(x-1) for x in ((ids+1)*(kmeans.labels_ == n)) if x > 0])

mat = []
matTest = []
n = 0
for ind in l:
    newDf = train.loc[train['stock_id'].isin(ind)]
    newDf = newDf.groupby(['time_id']).agg(np.nanmean)
    newDf.loc[:, 'stock_id'] = str(n)+'c1'
    mat.append(newDf)
    newDf = test.loc[test['stock_id'].isin(ind)]    
    newDf = newDf.groupby(['time_id']).agg(np.nanmean)
    newDf.loc[:, 'stock_id'] = str(n) + 'c1'
    matTest.append(newDf)
    n += 1
    
mat1 = pd.concat(mat).reset_index()
mat1.drop(columns=['target'], inplace=True)
mat2 = pd.concat(matTest).reset_index()

# %%
mat2 = pd.concat([mat2 ,mat1.loc[mat1.time_id==5]])
mat1 = mat1.pivot(index='time_id', columns='stock_id')
mat1.columns = ["_".join(x) for x in mat1.columns.ravel()]
mat1.reset_index(inplace=True)

mat2 = mat2.pivot(index='time_id', columns='stock_id')
mat2.columns = ["_".join(x) for x in mat2.columns.ravel()]
mat2.reset_index(inplace=True)

# %%
nnn = ['time_id',
     'log_return1_realized_volatility_0c1',
     'log_return1_realized_volatility_1c1',     
     'log_return1_realized_volatility_3c1',
     'log_return1_realized_volatility_4c1',     
     'log_return1_realized_volatility_6c1',
     'total_volume_mean_0c1',
     'total_volume_mean_1c1', 
     'total_volume_mean_3c1',
     'total_volume_mean_4c1', 
     'total_volume_mean_6c1',
     'trade_size_mean_0c1',
     'trade_size_mean_1c1', 
     'trade_size_mean_3c1',
     'trade_size_mean_4c1', 
     'trade_size_mean_6c1',
     'trade_order_count_mean_0c1',
     'trade_order_count_mean_1c1',
     'trade_order_count_mean_3c1',
     'trade_order_count_mean_4c1',
     'trade_order_count_mean_6c1',      
     'price_spread_mean_0c1',
     'price_spread_mean_1c1',
     'price_spread_mean_3c1',
     'price_spread_mean_4c1',
     'price_spread_mean_6c1',   
     'bid_spread_mean_0c1',
     'bid_spread_mean_1c1',
     'bid_spread_mean_3c1',
     'bid_spread_mean_4c1',
     'bid_spread_mean_6c1',       
     'ask_spread_mean_0c1',
     'ask_spread_mean_1c1',
     'ask_spread_mean_3c1',
     'ask_spread_mean_4c1',
     'ask_spread_mean_6c1',   
     'volume_imbalance_mean_0c1',
     'volume_imbalance_mean_1c1',
     'volume_imbalance_mean_3c1',
     'volume_imbalance_mean_4c1',
     'volume_imbalance_mean_6c1',       
     'bid_ask_spread_mean_0c1',
     'bid_ask_spread_mean_1c1',
     'bid_ask_spread_mean_3c1',
     'bid_ask_spread_mean_4c1',
     'bid_ask_spread_mean_6c1',
     'size_tau2_0c1',
     'size_tau2_1c1',
     'size_tau2_3c1',
     'size_tau2_4c1',
     'size_tau2_6c1']

# %%
train = pd.merge(train, mat1[nnn], how='left', on='time_id')
test = pd.merge(test, mat2[nnn], how='left', on='time_id')

# %%
# Function to calculate the root mean squared percentage error
def rmspe(y_true, y_pred):
    return np.sqrt(np.mean(np.square((y_true - y_pred) / y_true)))
# Function to early stop with root mean squared percentage error
def feval_rmspe(y_pred, lgb_train):
    y_true = lgb_train.get_label()
    return 'RMSPE', rmspe(y_true, y_pred), False


def train_and_evaluate(train, test):
    # Hyperparammeters (optimized)
    seed = 69
    params = {
        'learning_rate': 0.02,        
        'lambda_l1': 6.3,
        'num_leaves': 800,
        'min_sum_hessian_in_leaf': 18.2,
        'feature_fraction': 0.6,
        'feature_fraction_bynode': 0.9,
        'bagging_fraction': 0.9,
        'bagging_freq': 40,
        'min_data_in_leaf': 900,
        'max_depth': 5,
        'seed': seed,
        'feature_fraction_seed': seed,
        'bagging_seed': seed,
        'drop_seed': seed,
        'data_random_seed': seed,
        'objective': 'rmse',
        'boosting': 'gbdt',
        'verbosity': -1,
        'n_jobs': -1,
    }   
    
    # Split features and target
    x = train.drop(['row_id', 'target', 'time_id'], axis = 1)
    y = train['target']
    x_test = test.drop(['row_id', 'time_id'], axis = 1)
    # Transform stock id to a numeric value
    x['stock_id'] = x['stock_id'].astype(int)
    x_test['stock_id'] = x_test['stock_id'].astype(int)
    
    # Create out of folds array
    oof_predictions = np.zeros(x.shape[0])
    # Create test array to store predictions
    test_predictions = np.zeros(x_test.shape[0])
    # Create a KFold object
    kfold = model_selection.KFold(n_splits = 5, random_state = 69, shuffle = True)
    # Iterate through each fold
    for fold, (trn_ind, val_ind) in enumerate(kfold.split(x)):
        print(f'Training fold {fold + 1}')
        x_train, x_val = x.iloc[trn_ind], x.iloc[val_ind]
        y_train, y_val = y.iloc[trn_ind], y.iloc[val_ind]
        # Root mean squared percentage error weights
        train_weights = 1 / np.square(y_train)
        val_weights = 1 / np.square(y_val)
        train_dataset = lgb.Dataset(x_train, y_train, weight = train_weights, categorical_feature = ['stock_id'])
        val_dataset = lgb.Dataset(x_val, y_val, weight = val_weights, categorical_feature = ['stock_id'])
        model = lgb.train(params = params, 
                          train_set = train_dataset, 
                          valid_sets = [train_dataset, val_dataset], 
                          num_boost_round = 30000, 
                          early_stopping_rounds = 200, 
                          verbose_eval = 200,
                          feval = feval_rmspe)
        # Add predictions to the out of folds array
        oof_predictions[val_ind] = model.predict(x_val)
        # Predict the test set
        test_predictions += model.predict(x_test) / 5
        
    rmspe_score = rmspe(y, oof_predictions)
    print(f'Our out of folds RMSPE is {rmspe_score}')
    # Return test predictions
    return test_predictions


test_predictions = train_and_evaluate(train, test)
# Out:
# Training fold 1
# Training until validation scores don't improve for 200 rounds
# [200]	training's rmse: 0.000467087	training's RMSPE: 0.216172	valid_1's rmse: 0.000471153	valid_1's RMSPE: 0.218064
# [400]	training's rmse: 0.000450863	training's RMSPE: 0.208663	valid_1's rmse: 0.000457298	valid_1's RMSPE: 0.211652
# [600]	training's rmse: 0.000441466	training's RMSPE: 0.204314	valid_1's rmse: 0.000450113	valid_1's RMSPE: 0.208326
# [800]	training's rmse: 0.000433869	training's RMSPE: 0.200798	valid_1's rmse: 0.000444703	valid_1's RMSPE: 0.205822
# [1000]	training's rmse: 0.00042718	training's RMSPE: 0.197703	valid_1's rmse: 0.000440256	valid_1's RMSPE: 0.203764
# [1200]	training's rmse: 0.0004214	training's RMSPE: 0.195027	valid_1's rmse: 0.000436407	valid_1's RMSPE: 0.201982
# [1400]	training's rmse: 0.000416293	training's RMSPE: 0.192664	valid_1's rmse: 0.00043277	valid_1's RMSPE: 0.200299
# [1600]	training's rmse: 0.00041179	training's RMSPE: 0.19058	valid_1's rmse: 0.000430074	valid_1's RMSPE: 0.199051
# [1800]	training's rmse: 0.00040764	training's RMSPE: 0.188659	valid_1's rmse: 0.000427432	valid_1's RMSPE: 0.197829
# [2000]	training's rmse: 0.000403642	training's RMSPE: 0.186809	valid_1's rmse: 0.000425235	valid_1's RMSPE: 0.196812
# [2200]	training's rmse: 0.000400016	training's RMSPE: 0.185131	valid_1's rmse: 0.00042297	valid_1's RMSPE: 0.195764
# [2400]	training's rmse: 0.000397062	training's RMSPE: 0.183764	valid_1's rmse: 0.000421311	valid_1's RMSPE: 0.194996
# [2600]	training's rmse: 0.000394168	training's RMSPE: 0.182424	valid_1's rmse: 0.000419995	valid_1's RMSPE: 0.194387
# [2800]	training's rmse: 0.000391192	training's RMSPE: 0.181047	valid_1's rmse: 0.000418504	valid_1's RMSPE: 0.193696
# [3000]	training's rmse: 0.000388821	training's RMSPE: 0.17995	valid_1's rmse: 0.000417646	valid_1's RMSPE: 0.1933
# [3200]	training's rmse: 0.000386248	training's RMSPE: 0.178759	valid_1's rmse: 0.000416323	valid_1's RMSPE: 0.192687
# [3400]	training's rmse: 0.000383873	training's RMSPE: 0.177659	valid_1's rmse: 0.000415379	valid_1's RMSPE: 0.19225
# [3600]	training's rmse: 0.00038174	training's RMSPE: 0.176673	valid_1's rmse: 0.000414579	valid_1's RMSPE: 0.19188
# [3800]	training's rmse: 0.000379797	training's RMSPE: 0.175773	valid_1's rmse: 0.00041405	valid_1's RMSPE: 0.191635
# [4000]	training's rmse: 0.000377892	training's RMSPE: 0.174892	valid_1's rmse: 0.000413465	valid_1's RMSPE: 0.191364
# [4200]	training's rmse: 0.000376041	training's RMSPE: 0.174035	valid_1's rmse: 0.000412699	valid_1's RMSPE: 0.19101
# [4400]	training's rmse: 0.000374331	training's RMSPE: 0.173244	valid_1's rmse: 0.000412218	valid_1's RMSPE: 0.190787
# [4600]	training's rmse: 0.000372698	training's RMSPE: 0.172488	valid_1's rmse: 0.000411605	valid_1's RMSPE: 0.190503
# [4800]	training's rmse: 0.00037118	training's RMSPE: 0.171785	valid_1's rmse: 0.000411285	valid_1's RMSPE: 0.190355
# [5000]	training's rmse: 0.000369675	training's RMSPE: 0.171088	valid_1's rmse: 0.000411146	valid_1's RMSPE: 0.190291
# [5200]	training's rmse: 0.000368205	training's RMSPE: 0.170408	valid_1's rmse: 0.000410596	valid_1's RMSPE: 0.190036
# [5400]	training's rmse: 0.000366874	training's RMSPE: 0.169792	valid_1's rmse: 0.000410342	valid_1's RMSPE: 0.189919
# [5600]	training's rmse: 0.000365475	training's RMSPE: 0.169145	valid_1's rmse: 0.000409952	valid_1's RMSPE: 0.189738
# [5800]	training's rmse: 0.00036412	training's RMSPE: 0.168518	valid_1's rmse: 0.000409657	valid_1's RMSPE: 0.189602
# [6000]	training's rmse: 0.000362737	training's RMSPE: 0.167877	valid_1's rmse: 0.000409307	valid_1's RMSPE: 0.18944
# [6200]	training's rmse: 0.000361535	training's RMSPE: 0.167321	valid_1's rmse: 0.00040914	valid_1's RMSPE: 0.189363
# [6400]	training's rmse: 0.000360139	training's RMSPE: 0.166675	valid_1's rmse: 0.000408949	valid_1's RMSPE: 0.189274
# [6600]	training's rmse: 0.00035896	training's RMSPE: 0.16613	valid_1's rmse: 0.000408821	valid_1's RMSPE: 0.189215
# [6800]	training's rmse: 0.00035759	training's RMSPE: 0.165495	valid_1's rmse: 0.000408643	valid_1's RMSPE: 0.189133
# [7000]	training's rmse: 0.000356452	training's RMSPE: 0.164969	valid_1's rmse: 0.000408545	valid_1's RMSPE: 0.189087
# [7200]	training's rmse: 0.000355351	training's RMSPE: 0.164459	valid_1's rmse: 0.000408521	valid_1's RMSPE: 0.189076
# [7400]	training's rmse: 0.000354199	training's RMSPE: 0.163926	valid_1's rmse: 0.000408279	valid_1's RMSPE: 0.188964
# [7600]	training's rmse: 0.000353215	training's RMSPE: 0.163471	valid_1's rmse: 0.000408178	valid_1's RMSPE: 0.188917
# Early stopping, best iteration is:
# [7598]	training's rmse: 0.000353222	training's RMSPE: 0.163474	valid_1's rmse: 0.000408176	valid_1's RMSPE: 0.188916
# Training fold 2
# Training until validation scores don't improve for 200 rounds
# [200]	training's rmse: 0.000465809	training's RMSPE: 0.215877	valid_1's rmse: 0.000475702	valid_1's RMSPE: 0.218953
# [400]	training's rmse: 0.000449035	training's RMSPE: 0.208103	valid_1's rmse: 0.000461968	valid_1's RMSPE: 0.212632
# [600]	training's rmse: 0.000439474	training's RMSPE: 0.203672	valid_1's rmse: 0.000454542	valid_1's RMSPE: 0.209214
# [800]	training's rmse: 0.000431793	training's RMSPE: 0.200112	valid_1's rmse: 0.000448891	valid_1's RMSPE: 0.206613
# [1000]	training's rmse: 0.000425598	training's RMSPE: 0.197241	valid_1's rmse: 0.000444472	valid_1's RMSPE: 0.204579
# [1200]	training's rmse: 0.000420205	training's RMSPE: 0.194742	valid_1's rmse: 0.000440689	valid_1's RMSPE: 0.202838
# [1400]	training's rmse: 0.00041515	training's RMSPE: 0.192399	valid_1's rmse: 0.000437285	valid_1's RMSPE: 0.201271
# [1600]	training's rmse: 0.000410658	training's RMSPE: 0.190318	valid_1's rmse: 0.000434241	valid_1's RMSPE: 0.19987
# [1800]	training's rmse: 0.000406576	training's RMSPE: 0.188426	valid_1's rmse: 0.000431652	valid_1's RMSPE: 0.198678
# [2000]	training's rmse: 0.000403152	training's RMSPE: 0.186839	valid_1's rmse: 0.000429604	valid_1's RMSPE: 0.197735
# [2200]	training's rmse: 0.000399716	training's RMSPE: 0.185247	valid_1's rmse: 0.000427473	valid_1's RMSPE: 0.196755
# [2400]	training's rmse: 0.000396566	training's RMSPE: 0.183787	valid_1's rmse: 0.000425545	valid_1's RMSPE: 0.195867
# [2600]	training's rmse: 0.000393696	training's RMSPE: 0.182457	valid_1's rmse: 0.000423976	valid_1's RMSPE: 0.195145
# [2800]	training's rmse: 0.000390824	training's RMSPE: 0.181126	valid_1's rmse: 0.000422302	valid_1's RMSPE: 0.194374
# [3000]	training's rmse: 0.000388127	training's RMSPE: 0.179876	valid_1's rmse: 0.000420844	valid_1's RMSPE: 0.193703
# [3200]	training's rmse: 0.000385712	training's RMSPE: 0.178756	valid_1's rmse: 0.000419727	valid_1's RMSPE: 0.193189
# [3400]	training's rmse: 0.000383742	training's RMSPE: 0.177843	valid_1's rmse: 0.000418992	valid_1's RMSPE: 0.192851
# [3600]	training's rmse: 0.000381425	training's RMSPE: 0.17677	valid_1's rmse: 0.000417921	valid_1's RMSPE: 0.192358
# [3800]	training's rmse: 0.000379584	training's RMSPE: 0.175917	valid_1's rmse: 0.000417069	valid_1's RMSPE: 0.191966
# [4000]	training's rmse: 0.00037778	training's RMSPE: 0.17508	valid_1's rmse: 0.000416398	valid_1's RMSPE: 0.191657
# [4200]	training's rmse: 0.000375785	training's RMSPE: 0.174156	valid_1's rmse: 0.000415514	valid_1's RMSPE: 0.19125
# [4400]	training's rmse: 0.000373881	training's RMSPE: 0.173273	valid_1's rmse: 0.000414901	valid_1's RMSPE: 0.190968
# [4600]	training's rmse: 0.000372047	training's RMSPE: 0.172423	valid_1's rmse: 0.000414254	valid_1's RMSPE: 0.19067
# [4800]	training's rmse: 0.000370629	training's RMSPE: 0.171766	valid_1's rmse: 0.000414024	valid_1's RMSPE: 0.190564
# [5000]	training's rmse: 0.000369118	training's RMSPE: 0.171066	valid_1's rmse: 0.000413674	valid_1's RMSPE: 0.190403
# [5200]	training's rmse: 0.000367583	training's RMSPE: 0.170355	valid_1's rmse: 0.000413316	valid_1's RMSPE: 0.190238
# [5400]	training's rmse: 0.000366177	training's RMSPE: 0.169703	valid_1's rmse: 0.000412968	valid_1's RMSPE: 0.190078
# [5600]	training's rmse: 0.000364838	training's RMSPE: 0.169082	valid_1's rmse: 0.000412764	valid_1's RMSPE: 0.189984
# [5800]	training's rmse: 0.00036345	training's RMSPE: 0.168439	valid_1's rmse: 0.00041235	valid_1's RMSPE: 0.189794
# [6000]	training's rmse: 0.000362074	training's RMSPE: 0.167801	valid_1's rmse: 0.000411887	valid_1's RMSPE: 0.189581
# [6200]	training's rmse: 0.000360865	training's RMSPE: 0.167241	valid_1's rmse: 0.000411747	valid_1's RMSPE: 0.189517
# [6400]	training's rmse: 0.000359645	training's RMSPE: 0.166676	valid_1's rmse: 0.000411535	valid_1's RMSPE: 0.189419
# [6600]	training's rmse: 0.000358448	training's RMSPE: 0.166121	valid_1's rmse: 0.000411472	valid_1's RMSPE: 0.18939
# [6800]	training's rmse: 0.000357239	training's RMSPE: 0.165561	valid_1's rmse: 0.000411188	valid_1's RMSPE: 0.189259
# [7000]	training's rmse: 0.000356062	training's RMSPE: 0.165015	valid_1's rmse: 0.000411121	valid_1's RMSPE: 0.189228
# [7200]	training's rmse: 0.000354792	training's RMSPE: 0.164427	valid_1's rmse: 0.000410911	valid_1's RMSPE: 0.189132
# [7400]	training's rmse: 0.000353586	training's RMSPE: 0.163868	valid_1's rmse: 0.000410632	valid_1's RMSPE: 0.189003
# [7600]	training's rmse: 0.000352543	training's RMSPE: 0.163384	valid_1's rmse: 0.000410452	valid_1's RMSPE: 0.18892
# [7800]	training's rmse: 0.000351515	training's RMSPE: 0.162908	valid_1's rmse: 0.000410291	valid_1's RMSPE: 0.188846
# [8000]	training's rmse: 0.000350346	training's RMSPE: 0.162366	valid_1's rmse: 0.000410018	valid_1's RMSPE: 0.188721
# [8200]	training's rmse: 0.000349287	training's RMSPE: 0.161876	valid_1's rmse: 0.000409896	valid_1's RMSPE: 0.188664
# [8400]	training's rmse: 0.000348284	training's RMSPE: 0.16141	valid_1's rmse: 0.000409674	valid_1's RMSPE: 0.188562
# [8600]	training's rmse: 0.000347223	training's RMSPE: 0.160919	valid_1's rmse: 0.000409624	valid_1's RMSPE: 0.188539
# [8800]	training's rmse: 0.000346268	training's RMSPE: 0.160476	valid_1's rmse: 0.000409557	valid_1's RMSPE: 0.188508
# [9000]	training's rmse: 0.000345331	training's RMSPE: 0.160042	valid_1's rmse: 0.000409559	valid_1's RMSPE: 0.188509
# [9200]	training's rmse: 0.000344267	training's RMSPE: 0.159549	valid_1's rmse: 0.000409335	valid_1's RMSPE: 0.188406
# [9400]	training's rmse: 0.000343301	training's RMSPE: 0.159101	valid_1's rmse: 0.000409238	valid_1's RMSPE: 0.188362
# [9600]	training's rmse: 0.000342263	training's RMSPE: 0.15862	valid_1's rmse: 0.000409033	valid_1's RMSPE: 0.188267
# [9800]	training's rmse: 0.000341337	training's RMSPE: 0.158191	valid_1's rmse: 0.000409045	valid_1's RMSPE: 0.188272
# [10000]	training's rmse: 0.000340348	training's RMSPE: 0.157733	valid_1's rmse: 0.000408892	valid_1's RMSPE: 0.188202
# Early stopping, best iteration is:
# [9928]	training's rmse: 0.000340699	training's RMSPE: 0.157896	valid_1's rmse: 0.000408884	valid_1's RMSPE: 0.188199
# Training fold 3
# Training until validation scores don't improve for 200 rounds
# [200]	training's rmse: 0.000466632	training's RMSPE: 0.215809	valid_1's rmse: 0.000475615	valid_1's RMSPE: 0.220747
# [400]	training's rmse: 0.000450443	training's RMSPE: 0.208322	valid_1's rmse: 0.000463215	valid_1's RMSPE: 0.214992
# [600]	training's rmse: 0.000441561	training's RMSPE: 0.204215	valid_1's rmse: 0.000457432	valid_1's RMSPE: 0.212308
# [800]	training's rmse: 0.000433579	training's RMSPE: 0.200523	valid_1's rmse: 0.000451508	valid_1's RMSPE: 0.209558
# [1000]	training's rmse: 0.00042712	training's RMSPE: 0.197536	valid_1's rmse: 0.000446974	valid_1's RMSPE: 0.207454
# [1200]	training's rmse: 0.000420843	training's RMSPE: 0.194633	valid_1's rmse: 0.00044272	valid_1's RMSPE: 0.205479
# [1400]	training's rmse: 0.00041574	training's RMSPE: 0.192272	valid_1's rmse: 0.000439341	valid_1's RMSPE: 0.203911
# [1600]	training's rmse: 0.000411459	training's RMSPE: 0.190293	valid_1's rmse: 0.000436431	valid_1's RMSPE: 0.20256
# [1800]	training's rmse: 0.000407106	training's RMSPE: 0.188279	valid_1's rmse: 0.000433873	valid_1's RMSPE: 0.201373
# [2000]	training's rmse: 0.000403797	training's RMSPE: 0.186749	valid_1's rmse: 0.00043277	valid_1's RMSPE: 0.200861
# [2200]	training's rmse: 0.000400376	training's RMSPE: 0.185167	valid_1's rmse: 0.000431353	valid_1's RMSPE: 0.200204
# [2400]	training's rmse: 0.000397183	training's RMSPE: 0.18369	valid_1's rmse: 0.000430039	valid_1's RMSPE: 0.199594
# [2600]	training's rmse: 0.000394088	training's RMSPE: 0.182259	valid_1's rmse: 0.000428567	valid_1's RMSPE: 0.198911
# [2800]	training's rmse: 0.000391305	training's RMSPE: 0.180972	valid_1's rmse: 0.00042707	valid_1's RMSPE: 0.198216
# [3000]	training's rmse: 0.00038893	training's RMSPE: 0.179874	valid_1's rmse: 0.00042626	valid_1's RMSPE: 0.19784
# [3200]	training's rmse: 0.000386451	training's RMSPE: 0.178727	valid_1's rmse: 0.000425133	valid_1's RMSPE: 0.197317
# [3400]	training's rmse: 0.000384166	training's RMSPE: 0.17767	valid_1's rmse: 0.000424495	valid_1's RMSPE: 0.19702
# [3600]	training's rmse: 0.000382168	training's RMSPE: 0.176746	valid_1's rmse: 0.000423826	valid_1's RMSPE: 0.19671
# [3800]	training's rmse: 0.000380402	training's RMSPE: 0.175929	valid_1's rmse: 0.000423336	valid_1's RMSPE: 0.196483
# [4000]	training's rmse: 0.000378495	training's RMSPE: 0.175048	valid_1's rmse: 0.000422691	valid_1's RMSPE: 0.196184
# [4200]	training's rmse: 0.000376609	training's RMSPE: 0.174175	valid_1's rmse: 0.00042221	valid_1's RMSPE: 0.19596
# [4400]	training's rmse: 0.000374747	training's RMSPE: 0.173314	valid_1's rmse: 0.000421639	valid_1's RMSPE: 0.195695
# [4600]	training's rmse: 0.000373063	training's RMSPE: 0.172535	valid_1's rmse: 0.000421462	valid_1's RMSPE: 0.195613
# [4800]	training's rmse: 0.000371406	training's RMSPE: 0.171769	valid_1's rmse: 0.000420952	valid_1's RMSPE: 0.195376
# [5000]	training's rmse: 0.000369851	training's RMSPE: 0.17105	valid_1's rmse: 0.000420626	valid_1's RMSPE: 0.195225
# [5200]	training's rmse: 0.000368294	training's RMSPE: 0.17033	valid_1's rmse: 0.000420309	valid_1's RMSPE: 0.195078
# [5400]	training's rmse: 0.000366799	training's RMSPE: 0.169638	valid_1's rmse: 0.000419778	valid_1's RMSPE: 0.194831
# [5600]	training's rmse: 0.000365394	training's RMSPE: 0.168988	valid_1's rmse: 0.000419636	valid_1's RMSPE: 0.194766
# [5800]	training's rmse: 0.000363806	training's RMSPE: 0.168254	valid_1's rmse: 0.000419433	valid_1's RMSPE: 0.194671
# [6000]	training's rmse: 0.000362385	training's RMSPE: 0.167597	valid_1's rmse: 0.000419104	valid_1's RMSPE: 0.194518
# [6200]	training's rmse: 0.000361191	training's RMSPE: 0.167045	valid_1's rmse: 0.000419075	valid_1's RMSPE: 0.194505
# [6400]	training's rmse: 0.000359877	training's RMSPE: 0.166437	valid_1's rmse: 0.000419062	valid_1's RMSPE: 0.194499
# [6600]	training's rmse: 0.000358618	training's RMSPE: 0.165855	valid_1's rmse: 0.000418912	valid_1's RMSPE: 0.194429
# [6800]	training's rmse: 0.000357329	training's RMSPE: 0.165259	valid_1's rmse: 0.000418811	valid_1's RMSPE: 0.194383
# [7000]	training's rmse: 0.000356127	training's RMSPE: 0.164703	valid_1's rmse: 0.000418703	valid_1's RMSPE: 0.194332
# [7200]	training's rmse: 0.000354975	training's RMSPE: 0.16417	valid_1's rmse: 0.00041864	valid_1's RMSPE: 0.194303
# Early stopping, best iteration is:
# [7043]	training's rmse: 0.000355879	training's RMSPE: 0.164588	valid_1's rmse: 0.000418584	valid_1's RMSPE: 0.194277
# Training fold 4
# Training until validation scores don't improve for 200 rounds
# [200]	training's rmse: 0.000465695	training's RMSPE: 0.215594	valid_1's rmse: 0.000493072	valid_1's RMSPE: 0.22793
# [400]	training's rmse: 0.000449655	training's RMSPE: 0.208168	valid_1's rmse: 0.000478714	valid_1's RMSPE: 0.221292
# [600]	training's rmse: 0.000440288	training's RMSPE: 0.203831	valid_1's rmse: 0.000472059	valid_1's RMSPE: 0.218216
# [800]	training's rmse: 0.000432744	training's RMSPE: 0.200339	valid_1's rmse: 0.000466307	valid_1's RMSPE: 0.215557
# [1000]	training's rmse: 0.000425995	training's RMSPE: 0.197214	valid_1's rmse: 0.00046158	valid_1's RMSPE: 0.213372
# [1200]	training's rmse: 0.000419961	training's RMSPE: 0.194421	valid_1's rmse: 0.000457529	valid_1's RMSPE: 0.211499
# [1400]	training's rmse: 0.000415094	training's RMSPE: 0.192168	valid_1's rmse: 0.000454382	valid_1's RMSPE: 0.210045
# [1600]	training's rmse: 0.000410462	training's RMSPE: 0.190023	valid_1's rmse: 0.000451759	valid_1's RMSPE: 0.208832
# [1800]	training's rmse: 0.000406551	training's RMSPE: 0.188213	valid_1's rmse: 0.000449152	valid_1's RMSPE: 0.207627
# [2000]	training's rmse: 0.000402652	training's RMSPE: 0.186408	valid_1's rmse: 0.00044656	valid_1's RMSPE: 0.206429
# [2200]	training's rmse: 0.000399329	training's RMSPE: 0.184869	valid_1's rmse: 0.000444774	valid_1's RMSPE: 0.205603
# [2400]	training's rmse: 0.00039607	training's RMSPE: 0.18336	valid_1's rmse: 0.000442829	valid_1's RMSPE: 0.204704
# [2600]	training's rmse: 0.000393101	training's RMSPE: 0.181986	valid_1's rmse: 0.000441777	valid_1's RMSPE: 0.204217
# [2800]	training's rmse: 0.000390352	training's RMSPE: 0.180713	valid_1's rmse: 0.000440352	valid_1's RMSPE: 0.203559
# [3000]	training's rmse: 0.000387983	training's RMSPE: 0.179617	valid_1's rmse: 0.000439427	valid_1's RMSPE: 0.203131
# [3200]	training's rmse: 0.000385654	training's RMSPE: 0.178538	valid_1's rmse: 0.000439219	valid_1's RMSPE: 0.203035
# [3400]	training's rmse: 0.000383527	training's RMSPE: 0.177554	valid_1's rmse: 0.000438284	valid_1's RMSPE: 0.202603
# [3600]	training's rmse: 0.000381015	training's RMSPE: 0.176391	valid_1's rmse: 0.000437181	valid_1's RMSPE: 0.202093
# [3800]	training's rmse: 0.00037911	training's RMSPE: 0.175509	valid_1's rmse: 0.000436834	valid_1's RMSPE: 0.201933
# [4000]	training's rmse: 0.000377252	training's RMSPE: 0.174648	valid_1's rmse: 0.000436213	valid_1's RMSPE: 0.201645
# [4200]	training's rmse: 0.000375511	training's RMSPE: 0.173843	valid_1's rmse: 0.000435745	valid_1's RMSPE: 0.201429
# [4400]	training's rmse: 0.000373745	training's RMSPE: 0.173025	valid_1's rmse: 0.000434565	valid_1's RMSPE: 0.200884
# [4600]	training's rmse: 0.00037199	training's RMSPE: 0.172213	valid_1's rmse: 0.000433926	valid_1's RMSPE: 0.200588
# [4800]	training's rmse: 0.000370339	training's RMSPE: 0.171449	valid_1's rmse: 0.00043353	valid_1's RMSPE: 0.200405
# [5000]	training's rmse: 0.000368782	training's RMSPE: 0.170728	valid_1's rmse: 0.000433294	valid_1's RMSPE: 0.200296
# Early stopping, best iteration is:
# [4920]	training's rmse: 0.000369299	training's RMSPE: 0.170967	valid_1's rmse: 0.000433215	valid_1's RMSPE: 0.20026
# Training fold 5
# Training until validation scores don't improve for 200 rounds
# [200]	training's rmse: 0.000467912	training's RMSPE: 0.216352	valid_1's rmse: 0.000469065	valid_1's RMSPE: 0.217905
# [400]	training's rmse: 0.000451968	training's RMSPE: 0.208979	valid_1's rmse: 0.000455965	valid_1's RMSPE: 0.21182
# [600]	training's rmse: 0.000442685	training's RMSPE: 0.204687	valid_1's rmse: 0.000449268	valid_1's RMSPE: 0.208708
# [800]	training's rmse: 0.000434857	training's RMSPE: 0.201068	valid_1's rmse: 0.000443599	valid_1's RMSPE: 0.206075
# [1000]	training's rmse: 0.000427957	training's RMSPE: 0.197877	valid_1's rmse: 0.000438881	valid_1's RMSPE: 0.203883
# [1200]	training's rmse: 0.000422474	training's RMSPE: 0.195342	valid_1's rmse: 0.00043543	valid_1's RMSPE: 0.20228
# [1400]	training's rmse: 0.000417335	training's RMSPE: 0.192966	valid_1's rmse: 0.000432267	valid_1's RMSPE: 0.200811
# [1600]	training's rmse: 0.000412844	training's RMSPE: 0.190889	valid_1's rmse: 0.000429517	valid_1's RMSPE: 0.199534
# [1800]	training's rmse: 0.000408287	training's RMSPE: 0.188783	valid_1's rmse: 0.000426986	valid_1's RMSPE: 0.198357
# [2000]	training's rmse: 0.000404727	training's RMSPE: 0.187136	valid_1's rmse: 0.000425153	valid_1's RMSPE: 0.197506
# [2200]	training's rmse: 0.0004009	training's RMSPE: 0.185367	valid_1's rmse: 0.000423023	valid_1's RMSPE: 0.196516
# [2400]	training's rmse: 0.000397851	training's RMSPE: 0.183957	valid_1's rmse: 0.000421745	valid_1's RMSPE: 0.195923
# [2600]	training's rmse: 0.000394961	training's RMSPE: 0.182621	valid_1's rmse: 0.000420538	valid_1's RMSPE: 0.195362
# [2800]	training's rmse: 0.000392486	training's RMSPE: 0.181477	valid_1's rmse: 0.000419483	valid_1's RMSPE: 0.194872
# [3000]	training's rmse: 0.000389748	training's RMSPE: 0.18021	valid_1's rmse: 0.000418042	valid_1's RMSPE: 0.194203
# [3200]	training's rmse: 0.00038702	training's RMSPE: 0.178949	valid_1's rmse: 0.000416506	valid_1's RMSPE: 0.193489
# [3400]	training's rmse: 0.00038476	training's RMSPE: 0.177904	valid_1's rmse: 0.000415882	valid_1's RMSPE: 0.193199
# [3600]	training's rmse: 0.000382632	training's RMSPE: 0.17692	valid_1's rmse: 0.000415059	valid_1's RMSPE: 0.192817
# [3800]	training's rmse: 0.000380703	training's RMSPE: 0.176028	valid_1's rmse: 0.000414455	valid_1's RMSPE: 0.192536
# [4000]	training's rmse: 0.000378761	training's RMSPE: 0.17513	valid_1's rmse: 0.000413944	valid_1's RMSPE: 0.192299
# [4200]	training's rmse: 0.000376761	training's RMSPE: 0.174205	valid_1's rmse: 0.000413049	valid_1's RMSPE: 0.191883
# [4400]	training's rmse: 0.00037498	training's RMSPE: 0.173382	valid_1's rmse: 0.000412422	valid_1's RMSPE: 0.191592
# [4600]	training's rmse: 0.000373214	training's RMSPE: 0.172565	valid_1's rmse: 0.000412078	valid_1's RMSPE: 0.191432
# [4800]	training's rmse: 0.000371579	training's RMSPE: 0.17181	valid_1's rmse: 0.000411563	valid_1's RMSPE: 0.191193
# [5000]	training's rmse: 0.000369874	training's RMSPE: 0.171021	valid_1's rmse: 0.000411006	valid_1's RMSPE: 0.190934
# [5200]	training's rmse: 0.000368535	training's RMSPE: 0.170402	valid_1's rmse: 0.000410861	valid_1's RMSPE: 0.190867
# [5400]	training's rmse: 0.000366979	training's RMSPE: 0.169683	valid_1's rmse: 0.000410756	valid_1's RMSPE: 0.190818
# [5600]	training's rmse: 0.000365491	training's RMSPE: 0.168995	valid_1's rmse: 0.000410324	valid_1's RMSPE: 0.190617
# [5800]	training's rmse: 0.000364025	training's RMSPE: 0.168317	valid_1's rmse: 0.000409949	valid_1's RMSPE: 0.190443
# [6000]	training's rmse: 0.000362843	training's RMSPE: 0.16777	valid_1's rmse: 0.000409855	valid_1's RMSPE: 0.190399
# [6200]	training's rmse: 0.000361554	training's RMSPE: 0.167174	valid_1's rmse: 0.00040956	valid_1's RMSPE: 0.190262
# [6400]	training's rmse: 0.000360312	training's RMSPE: 0.1666	valid_1's rmse: 0.000409291	valid_1's RMSPE: 0.190137
# Early stopping, best iteration is:
# [6396]	training's rmse: 0.000360333	training's RMSPE: 0.16661	valid_1's rmse: 0.000409283	valid_1's RMSPE: 0.190134
# Our out of folds RMSPE is 0.19240919439442478

# %%
# Save test predictions
test['target'] = test_predictions
test[['row_id', 'target']].to_csv('submission.csv', index = False)
