# %% [markdown]
# ## Imports

# %%
import os
import gc
import random
import pickle
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
from joblib import Parallel, delayed

from scipy.optimize import minimize
from sklearn.cluster import KMeans
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler, LabelEncoder, QuantileTransformer

tqdm.pandas()
# %matplotlib inline

import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras import Model, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import get_custom_objects
from tensorflow.keras.layers import Activation, Embedding, Concatenate, Dense, Flatten

import warnings
warnings.filterwarnings("ignore")

def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)


SEED = 2021
seed_everything(SEED)

# %% [markdown]
# # Feature Utils

# %%
# feature utils
def calculate_wap(df, rank="1"):
    return (df[f"bid_price{rank}"] * df[f"ask_size{rank}"] + df[f"bid_size{rank}"] * df[f"ask_price{rank}"]) / (
                df[f"bid_size{rank}"] + df[f"ask_size{rank}"])


def calculate_agg_wap(df):
    wap1 = df["bid_price1"] * df["ask_size1"] + df["bid_size1"] * df["ask_price1"]
    wap2 = df["bid_price2"] * df["ask_size2"] + df["bid_size2"] * df["ask_price2"]
    den = df["ask_size1"] + df["ask_size2"] + df["bid_size1"] + df["bid_size2"]
    
    return (wap1 + wap2)/den
    pass


def calculate_inter_wap(df, rank="1"):
    return (df[f"bid_price{rank}"] * df[f"bid_size{rank}"] + df[f"ask_size{rank}"] * df[f"ask_price{rank}"]) / (
            df[f"bid_size{rank}"] + df[f"ask_size{rank}"])
    pass

def calculate_agg_inter_wap(df):
    iwap1 = df["bid_price1"] * df["bid_size1"] + df["ask_size1"] * df["ask_price1"]
    iwap2 = df["bid_price2"] * df["bid_size2"] + df["ask_size2"] * df["ask_price2"]
    den = df["ask_size1"] + df["ask_size2"] + df["bid_size1"] + df["bid_size2"]
    
    return (iwap1 + iwap2)/den
    pass


def calc_depth(df):
    depth = df['bid_price1'] * df['bid_size1'] + df['ask_price1'] * df['ask_size1'] + df['bid_price2'] * df[
               'bid_size2'] + df['ask_price2'] * df['ask_size2']
    return depth


def calc_slope(df):
    v0 = (df['bid_size1']+df['ask_size1'])/2
    p0 = (df['bid_price1']+df['ask_price1'])/2
    slope_bid = ((df['bid_size1']/v0)-1)/abs((df['bid_price1']/p0)-1)+(
                (df['bid_size2']/df['bid_size1'])-1)/abs((df['bid_price2']/df['bid_price1'])-1)
    slope_ask = ((df['ask_size1']/v0)-1)/abs((df['ask_price1']/p0)-1)+(
                (df['ask_size2']/df['ask_size1'])-1)/abs((df['ask_price2']/df['ask_price1'])-1)
    return (slope_bid+slope_ask)/2, abs(slope_bid-slope_ask)


def calc_dispersion(df):
    bspread = df['bid_price1'] - df['bid_price2']
    aspread = df['ask_price2'] - df['ask_price1']
    bmid = (df['bid_price1'] + df['ask_price1'])/2  - df['bid_price1']
    bmid2 = (df['bid_price1'] + df['ask_price1'])/2  - df['bid_price2']
    amid = df['ask_price1'] - (df['bid_price1'] + df['ask_price1'])/2
    amid2 = df['ask_price2'] - (df['bid_price1'] + df['ask_price1'])/2
    bdisp = (df['bid_size1']*bmid + df['bid_size2']*bspread)/(df['bid_size1']+df['bid_size2'])
    bdisp2 = (df['bid_size1']*bmid + df['bid_size2']*bmid2)/(df['bid_size1']+df['bid_size2'])
    adisp = (df['ask_size1']*amid + df['ask_size2']*aspread)/(df['ask_size1']+df['ask_size2'])      
    adisp2 = (df['ask_size1']*amid + df['ask_size2']*amid2)/(df['ask_size1']+df['ask_size2'])
    return (bdisp + adisp)/2, (bdisp2 + adisp2)/2

def calc_price_impact(df):
    ask = (df['ask_price1'] * df['ask_size1'] + df['ask_price2'] * df['ask_size2'])/(df['ask_size1']+df['ask_size2'])
    bid = (df['bid_price1'] * df['bid_size1'] + df['bid_price2'] * df['bid_size2'])/(df['bid_size1']+df['bid_size2'])
    return (df['ask_price1'] - ask)/df['ask_price1'], (df['bid_price1'] - bid)/df['bid_price1']


def calc_ofi(df):
    a = df['bid_size1']*np.where(df['bid_price1'].diff()>=0,1,0)
    b = df['bid_size1'].shift()*np.where(df['bid_price1'].diff()<=0,1,0)
    c = df['ask_size1']*np.where(df['ask_price1'].diff()<=0,1,0)
    d = df['ask_size1'].shift()*np.where(df['ask_price1'].diff()>=0,1,0)
    return a - b - c + d


def calc_tt1(df):
    p1 = df['ask_price1'] * df['ask_size1'] + df['bid_price1'] * df['bid_size1']
    p2 = df['ask_price2'] * df['ask_size2'] + df['bid_price2'] * df['bid_size2']      
    return p2 - p1 


def calculate_log_return(series):
    return np.log(series).diff()


def calculate_rv(series):
    return np.sqrt(np.sum(np.square(series)))

    
# Calculate integrated quarticity
def calculate_rv_quarticity(series):
    return (series.count()/3)*np.sum(series**4)

# Calculate weighted volatility
def calculate_rv_vol_weighted(series):
    return np.sqrt(np.sum(series**2)/series.count())


def count_unique(series):
    return len(np.unique(series))


def get_stats_window(df, seconds_in_bucket, features_dict, add_suffix=False):
    df_feature = df[df["seconds_in_bucket"] >= seconds_in_bucket].groupby(["time_id"]).agg(features_dict).reset_index()
    df_feature.columns = ["_".join(col) for col in df_feature.columns]

    if add_suffix:
        df_feature = df_feature.add_suffix("_" + str(seconds_in_bucket))

    return df_feature
    pass


def window_stats(df, feature_dict, feature_dict_time, second_windows, additional_dfs=None):
    df_merged = get_stats_window(df, seconds_in_bucket=0, features_dict=feature_dict)

    if additional_dfs is not None:
        df_merged = df_merged.merge(additional_dfs, how='left', left_on='time_id_', right_on='time_id')

    temp_dfs = []
    for window in second_windows:
        temp_dfs.append(
            (window,
             get_stats_window(df, seconds_in_bucket=window, features_dict=feature_dict_time, add_suffix=True)
             )
        )

    for window, temp_df in temp_dfs:
        df_merged = df_merged.merge(temp_df, how="left", left_on="time_id_", right_on=f"time_id__{window}")
        df_merged.drop(columns=[f"time_id__{window}"], inplace=True)

    return df_merged
    pass


def tendency(price, vol):
    diff = np.diff(price)
    val = (diff / price[1:]) * 100
    power = np.sum(val * vol[1:])
    return power
    pass


def get_stock_clusters(df, n_clusters=6):
    pivoted_data = df.pivot(index="time_id", columns=["stock_id"], values="target")
    corr_pivoted = pivoted_data.corr()

    clusters = KMeans(n_clusters, random_state=cfg.random_state).fit(corr_pivoted.values)

    groups = []
    for i in range(n_clusters):
        groups.append([x-1] for x in (corr_pivoted.index+1)*(clusters.labels_ == i) if x > 0)
    return groups
    pass


def create_cluster_aggregations(df, groups):
    feats = []

    for i, idx in enumerate(groups):
        chunk_df = df.loc[df['stock_id'].isin(idx)]
        chunk_df = chunk_df.groupby(['time_id']).agg(np.nanmean)
        chunk_df.loc[:, 'stock_id'] = str(i) + 'c1'
        feats.append(chunk_df)

    feats = pd.concat(feats).reset_index()
    if "target" in feats.columns:
        feats.drop(columns=['target'], inplace=True)

    feats = feats.pivot(index='time_id', columns='stock_id')
    feats.columns = ["_".join(x) for x in feats.columns.ravel()]
    feats.reset_index(inplace=True)

    return pd.merge(df, feats, how="left", on="time_id")
    pass

# %% [markdown]
# # Config

# %%
# config
class cfg:
    
    paths = {
        # train path
        "train_csv"  : "../input/optiver-realized-volatility-prediction/train.csv",
        "train_book" : "../input/optiver-realized-volatility-prediction/book_train.parquet",
        "train_trade": "../input/optiver-realized-volatility-prediction/trade_train.parquet",

        # test path
        "test_csv"   : "../input/optiver-realized-volatility-prediction/test.csv",
        "test_book"  : "../input/optiver-realized-volatility-prediction/book_test.parquet",
        "test_trade" : "../input/optiver-realized-volatility-prediction/trade_test.parquet",
        
        # model paths
        "dae": "./dae"
    }

    feature_dict_book = {
        "seconds_in_bucket": [count_unique],
        "wap1":              [np.sum, np.mean, np.std, np.max],
        "wap2":              [np.sum, np.mean, np.std, np.max],
        "wap_agg":           [np.sum, np.mean, np.std, np.max],
        
        "iwap1":             [np.sum, np.mean, np.std, np.max],
        "iwap2":             [np.sum, np.mean, np.std, np.max],
        "iwap_agg":          [np.sum, np.mean, np.std, np.max],
        
        "log_return1":       [np.sum, calculate_rv, calculate_rv_quarticity, calculate_rv_vol_weighted, np.mean, np.std],
        "log_return2":       [np.sum, calculate_rv, calculate_rv_quarticity, calculate_rv_vol_weighted, np.mean, np.std],
        'log_return_agg':    [np.sum, calculate_rv, calculate_rv_quarticity, calculate_rv_vol_weighted, np.mean, np.std],
        
        "inter_log_return1": [np.sum, calculate_rv, calculate_rv_quarticity, calculate_rv_vol_weighted, np.mean, np.std],
        "inter_log_return2": [np.sum, calculate_rv, calculate_rv_quarticity, calculate_rv_vol_weighted, np.mean, np.std],
        'inter_log_return_agg': [np.sum, calculate_rv, calculate_rv_quarticity, calculate_rv_vol_weighted, np.mean, np.std],
        
        "wap_balance":       [np.sum, np.mean, np.std, np.max],
        "volume_imbalance":  [np.sum, np.mean, np.std, np.max],
        "total_volume":      [np.sum, np.mean, np.std, np.max],
        
        "price_spread1":     [np.sum, np.mean, np.std, np.max],
        "price_spread2":     [np.sum, np.mean, np.std, np.max],
        "bid_spread":        [np.sum, np.mean, np.std, np.max],
        "ask_spread":        [np.sum, np.mean, np.std, np.max],
        
        'depth':             [np.sum, np.mean, np.std, np.max],
        'slope':             [np.sum, np.mean, np.std, np.max],
        'dispersion':        [np.sum, np.mean, np.std, np.max],
        'price_impact':      [np.sum, np.mean, np.std, np.max],
        'ofi':               [np.sum, np.mean, np.std, np.max],
        'turn_over':         [np.sum, np.mean, np.std, np.max],
    }

    feature_dict_book_time = {        
        "log_return1":       [calculate_rv, calculate_rv_quarticity, calculate_rv_vol_weighted],
        "log_return2":       [calculate_rv, calculate_rv_quarticity, calculate_rv_vol_weighted],
        "log_return_agg":    [calculate_rv, calculate_rv_quarticity, calculate_rv_vol_weighted],
        
        "inter_log_return1": [calculate_rv, calculate_rv_quarticity, calculate_rv_vol_weighted],
        "inter_log_return2": [calculate_rv, calculate_rv_quarticity, calculate_rv_vol_weighted],
        "inter_log_return_agg": [calculate_rv, calculate_rv_quarticity, calculate_rv_vol_weighted],
    }

    feature_dict_trade = {
        'seconds_in_bucket': [count_unique],       
        'log_return':        [np.sum, calculate_rv, calculate_rv_quarticity, calculate_rv_vol_weighted, np.mean, np.std],
        'size':              [np.sum, np.mean, np.std, np.max],
        'order_count':       [np.sum, np.mean, np.std, np.max],
        'amount':            [np.sum, np.mean, np.std, np.max],
    }
    
    feature_dict_trade_time = {
        'log_return':        [calculate_rv, calculate_rv_quarticity, calculate_rv_vol_weighted],
        'seconds_in_bucket': [count_unique],
        'size':              [np.sum, np.std],
        'order_count':       [np.sum, np.std],
        'amount':            [np.sum, np.std],
    }
    
    bucket_windows = [100, 200, 300, 400, 500]
    random_state = SEED
    pass

# %% [markdown]
# # Create Features

# %%
# order book features
def get_book_features(file_path):
    book_df = pd.read_parquet(file_path)

    # calculate wap
    book_df['wap1'] = calculate_wap(book_df, rank="1")
    book_df['wap2'] = calculate_wap(book_df, rank="2")
    book_df["wap_agg"] = calculate_agg_wap(book_df)
    
    book_df['iwap1'] = calculate_inter_wap(book_df, rank="1")
    book_df['iwap2'] = calculate_inter_wap(book_df, rank="2")
    book_df["iwap_agg"] = calculate_agg_inter_wap(book_df)

    # calculate log return
    book_df["log_return1"] = book_df.groupby(["time_id"])["wap1"].apply(calculate_log_return)
    book_df["log_return2"] = book_df.groupby(["time_id"])["wap2"].apply(calculate_log_return)
    book_df["log_return_agg"] = book_df.groupby(["time_id"])["wap_agg"].apply(calculate_log_return)
    
    book_df["inter_log_return1"] = book_df.groupby(["time_id"])["iwap1"].apply(calculate_log_return)
    book_df["inter_log_return2"] = book_df.groupby(["time_id"])["iwap2"].apply(calculate_log_return)
    book_df["inter_log_return_agg"] = book_df.groupby(["time_id"])["iwap_agg"].apply(calculate_log_return)

    # calculate balance
    book_df["wap_balance"] = abs(book_df["wap1"] - book_df["wap2"])
    book_df["volume_imbalance"] = abs(
        (book_df["ask_size1"] + book_df["ask_size2"]) - (book_df["bid_size1"] + book_df["bid_size2"]))
    book_df["total_volume"] = book_df["ask_size1"] + book_df["ask_size2"] + book_df["bid_size1"] + book_df[
        "bid_size2"]

    # calculate spread
    book_df["price_spread1"] = (book_df["ask_price1"] - book_df["bid_price1"]) / (
            (book_df["ask_price1"] + book_df["bid_price1"]) / 2)
    book_df["price_spread2"] = (book_df["ask_price2"] - book_df["bid_price2"]) / (
            (book_df["ask_price2"] + book_df["bid_price2"]) / 2)
    book_df["bid_spread"] = book_df["bid_price1"] - book_df["bid_price2"]
    book_df["ask_spread"] = book_df["ask_price1"] - book_df["ask_price2"]
    
    book_df["depth"] = calc_depth(book_df)
    book_df["slope"], _ = calc_slope(book_df)
    book_df["dispersion"], _ = calc_dispersion(book_df)
    book_df["price_impact"], _ = calc_price_impact(book_df)
    book_df["ofi"] = calc_ofi(book_df)
    book_df["turn_over"] = calc_tt1(book_df)
    
    book_df_merged = window_stats(book_df, cfg.feature_dict_book, cfg.feature_dict_book_time, cfg.bucket_windows)

    book_df_merged["row_id"] = book_df_merged["time_id_"].apply(lambda x: f"{file_path.split('=')[1]}-{x}")
    book_df_merged.drop(["time_id_"], axis=1, inplace=True)

    return book_df_merged.bfill().ffill()
                                                                
# trade features
def get_trade_price_features(df):
    res = []
    for n_time_id in df['time_id'].unique():
        df_id = df[df['time_id'] == n_time_id]
        vol_tendency = tendency(df_id['price'].values, df_id['size'].values)
        f_max = np.sum(df_id['price'].values > np.mean(df_id['price'].values))
        f_min = np.sum(df_id['price'].values < np.mean(df_id['price'].values))
        df_max = np.sum(np.diff(df_id['price'].values) > 0)
        df_min = np.sum(np.diff(df_id['price'].values) < 0)
        abs_diff = np.median(np.abs(df_id['price'].values - np.mean(df_id['price'].values)))
        energy = np.mean(df_id['price'].values ** 2)
        iqr_p = np.percentile(df_id['price'].values, 75) - np.percentile(df_id['price'].values, 25)
        abs_diff_v = np.median(np.abs(df_id['size'].values - np.mean(df_id['size'].values)))
        energy_v = np.sum(df_id['size'].values ** 2)
        iqr_p_v = np.percentile(df_id['size'].values, 75) - np.percentile(df_id['size'].values, 25)

        res.append({'time_id': n_time_id,
                    'tendency': vol_tendency,
                    'f_max': f_max,
                    'f_min': f_min,
                    'df_max': df_max,
                    'df_min': df_min,
                    'abs_diff': abs_diff,
                    'energy': energy,
                    'iqr_p': iqr_p,
                    'abs_diff_v': abs_diff_v,
                    'energy_v': energy_v,
                    'iqr_p_v': iqr_p_v})

    return pd.DataFrame(res)
    pass


def tau_features(df, sec, weight):
    tau_feat = 'tau_' + str(sec)
    bucket_col = 'trade_seconds_in_bucket_count_unique_' + str(sec)
    df[tau_feat] = np.sqrt(weight/df[bucket_col])

    size_feat = 'size_' + str(sec)
    order_col = 'trade_order_count_sum_' + str(sec)
    df[size_feat] = np.sqrt(weight/df[order_col])

    return df
    pass


def get_trade_features(file_path, buck_windows=cfg.bucket_windows):
    trade_df = pd.read_parquet(file_path)

    trade_df["log_return"] = trade_df.groupby(["time_id"])["price"].apply(calculate_log_return)
    trade_df["amount"] = trade_df["size"] * trade_df["price"]

    price_features = get_trade_price_features(trade_df)
    trade_df_merged = window_stats(trade_df, cfg.feature_dict_trade, cfg.feature_dict_trade_time, buck_windows, additional_dfs=price_features)

    trade_df_merged = trade_df_merged.add_prefix("trade_")

    trade_df_merged["row_id"] = trade_df_merged["trade_time_id_"].apply(lambda x: f"{file_path.split('=')[1]}-{x}")
    trade_df_merged.drop(["trade_time_id_"], axis=1, inplace=True)

    for sec in buck_windows:
        trade_df_merged = tau_features(trade_df_merged, sec, weight=sec/600)
    return trade_df_merged.bfill().ffill()

# %% [markdown]
# # Create Dataset

# %%
# create dataset
class GetData:
    def __init__(self, df, book_path, trade_path, is_train=True):
        self.df = df.copy(deep=True)
        self.order_book_path = book_path
        self.trade_path = trade_path
        self.is_train = is_train

        self._get_rowid()

    def _get_rowid(self):
        self.df["row_id"] = self.df["stock_id"].astype(str) + "-" + self.df["time_id"].astype(str)

    def get_time_stock(self, buck_windows=cfg.bucket_windows):
        vol_cols = []
        feat_set = ['log_return1_calculate_rv', 'log_return2_calculate_rv', 'log_return_agg_calculate_rv', 'trade_log_return_calculate_rv']
        for feat in feat_set:
            for sec in buck_windows:
                vol_cols.append(feat + f'_{sec}')
        vol_cols += feat_set

        df_stock_id = self.df.groupby(['stock_id'])[vol_cols].agg(['mean', 'std', 'max', 'min']).reset_index()
        df_stock_id.columns = ['_'.join(col) for col in df_stock_id.columns]
        df_stock_id = df_stock_id.add_suffix('_' + 'stock')

        df_time_id = self.df.groupby(['time_id'])[vol_cols].agg(['mean', 'std', 'max', 'min']).reset_index()
        df_time_id.columns = ['_'.join(col) for col in df_time_id.columns]
        df_time_id = df_time_id.add_suffix('_' + 'time')

        # Merge with original dataframe
        self.df = self.df.merge(df_stock_id, how='left', left_on=['stock_id'], right_on=['stock_id__stock'])
        self.df = self.df.merge(df_time_id, how='left', left_on=['time_id'], right_on=['time_id__time'])
        self.df.drop(['stock_id__stock', 'time_id__time'], axis=1, inplace=True)
        return self.df

    def process_features(self, list_stock_ids):
        def parallel_helper(stock_id):
            book_sample_path = os.path.join(self.order_book_path, f"stock_id={stock_id}")
            trade_sample_path = os.path.join(self.trade_path, f"stock_id={stock_id}")

            return pd.merge(get_book_features(book_sample_path), get_trade_features(trade_sample_path),
                            on="row_id",
                            how="left")

        df = Parallel(n_jobs=-1, verbose=1)(delayed(parallel_helper)(stock_id) for stock_id in list_stock_ids)
        df = pd.concat(df, ignore_index=True)

        return df

    def _get_features(self):
        features_df = self.process_features(self.df["stock_id"].unique())
        self.df = self.df.merge(features_df, on=["row_id"], how="left")

        return self.get_time_stock()
        pass

    def get_all_features(self, stock_groups):
        return create_cluster_aggregations(self._get_features(), stock_groups)
        pass

# %% [markdown]
# # Modeling

# %%
def swish(x, beta = 1):
    return (x * K.sigmoid(beta * x))

def rmspe(y_true, y_pred):
    return np.sqrt(np.mean(np.square((y_true-y_pred)/y_true)))
    pass

def root_mean_squared_per_error(y_true, y_pred):
         return K.sqrt(K.mean(K.square((y_true-y_pred)/y_true)))

# add as activation
get_custom_objects().update({'swish': Activation(swish)})

def create_autoencoder(input_dim, output_dim, noise=0.05):
    inp = tf.keras.layers.Input(shape=(input_dim, ))
    encoded = tf.keras.layers.GaussianNoise(noise)(inp)
    encoded = tf.keras.layers.Dense(32, activation='swish')(encoded)
    
    decoded = tf.keras.layers.Dropout(0.2)(encoded)
    decoded = tf.keras.layers.Dense(input_dim,name='decoded')(decoded)
    
    x = tf.keras.layers.Dense(16, activation='swish')(decoded)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(0.2)(x)
    x = tf.keras.layers.Dense(output_dim, activation='linear', name='label_output')(x)
    
    encoder = tf.keras.models.Model(inputs=inp, outputs=encoded)
    autoencoder = tf.keras.models.Model(inputs=inp, outputs=[decoded, x])
    
    autoencoder.compile(optimizer=tf.keras.optimizers.Adam(0.001), 
                        loss={'decoded':'mse',
                              'label_output':root_mean_squared_per_error})
    return autoencoder, encoder

def base_model(input_dim, output_dim, encoder):
    stock_id_input = tf.keras.Input(shape=(487,), name='stock_id')
    inputs = tf.keras.Input(shape=(input_dim,), name='num_data')
    
    x = encoder(stock_id_input)
    x = tf.keras.layers.Concatenate()([x, inputs])
    x = tf.keras.layers.BatchNormalization()(x)

    x = tf.keras.layers.Dense(4096, activation='swish')(x)
    x = tf.keras.layers.Reshape((256, 16))(x)
    x = tf.keras.layers.Conv1D(filters=16,
                               kernel_size=7,
                               strides=1,
                               activation='swish')(x)
    x = tf.keras.layers.MaxPooling1D(pool_size=2)(x)
    x = tf.keras.layers.Flatten()(x)
    

    for i in range(2):
        x = tf.keras.layers.Dense(256//(2 ** i), activation='swish')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.GaussianNoise(0.01)(x)
        x = tf.keras.layers.Dropout(0.2)(x)
    x = tf.keras.layers.Dense(output_dim, activation='linear')(x)
    
    model = tf.keras.models.Model(inputs=[stock_id_input, inputs], outputs=x)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                  loss=root_mean_squared_per_error, 
                  metrics=root_mean_squared_per_error)
    
    return model


def encode_stocks(df):
    stock_encoder = LabelEncoder()
    df["stock_id"] = stock_encoder.fit_transform(df["stock_id"])
    pickle.dump(stock_encoder, open("./label_stocks_global.pkl", "wb"))
    return df
    pass

def get_quantile_transform(train_df, test_df=None):
    print("[INFO] Applying Quantile Transformation...")
    for col in tqdm(train_df.columns):
        if col=="stock_id":
            continue
        qt = QuantileTransformer(random_state=21, n_quantiles=2000, output_distribution='normal')
        train_df[col] = qt.fit_transform(train_df[[col]])
        if test_df is not None: test_df[col] = qt.transform(test_df[[col]])
            
        del qt
        _ = gc.collect()
        
    return train_df, test_df
    pass


def get_transform(df, val_df, name, file_path=None):
    print(f"[INFO] Using {name} scaler...\n")
    if name=="mm":
        for col in tqdm(df.columns):
            if col=="stock_id":
                continue
            scaler = MinMaxScaler()
            df[col] = scaler.fit_transform(df[[col]])
            if val_df is not None: val_df[col] = scaler.transform(val_df[[col]])
            
    elif name=="mm_11":
        for col in tqdm(df.columns):
            if col=="stock_id":
                continue
            scaler = MinMaxScaler(feature_range=(-1, 1))
            df[col] = scaler.fit_transform(df[[col]])
            if val_df is not None: val_df[col] = scaler.transform(val_df[[col]])
    else:
        for col in tqdm(df.columns):
            if col=="stock_id":
                continue
            scaler = StandardScaler()
            df[col] = scaler.fit_transform(df[[col]])
            if val_df is not None: val_df[col] = scaler.transform(val_df[[col]])
    
    return df, val_df
    pass

class TrainFer:
    def __init__(self, n_splits, model_path, random_state):
        self.n_splits = n_splits
        self.random_state = random_state
        self.model_path = model_path
        if not os.path.isdir(model_path):
            os.makedirs(model_path)
            
    
    def get_encoder(self, X, y, scaler_name):
        if os.path.exists("../input/dataorvpprocessed/encoder.h5"):
            print("[INFO] Loading trained Encoder...")
            _, encoder = create_autoencoder(487, 1, noise=0.2)
            encoder.load_weights("../input/dataorvpprocessed/encoder.h5")
         
        else:
            X, _ = get_quantile_transform(X)
            X, _ = get_transform(X, None, scaler_name, f"./fulldata_{scaler_name}.pkl")

            autoencoder, encoder = create_autoencoder(487, 1, noise=0.2)
            autoencoder.fit(X,
                            (X, y),
                            epochs=100,
                            batch_size=512,
                            validation_split=0.2,
                            callbacks=[tf.keras.callbacks.EarlyStopping('val_loss', patience=15, restore_best_weights=True),
                                      tf.keras.callbacks.ModelCheckpoint(os.path.join(self.model_path, "dae.h5"), save_weights_only=True),
                                      tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=7, verbose=1, mode='min')])
            encoder.save_weights(os.path.join(self.model_path, "encoder.h5"))
            
            del X, y, autoencoder
            _ = gc.collect()   
            
        return encoder
        pass
    
    def train(self, X, y, callback_list, scaler_name="mm"):
        X = encode_stocks(X)
        encoder = self.get_encoder(X, y, scaler_name)
        encoder.trainable = False
        
        oof_predictions = np.zeros(X.shape[0])
        kfold = KFold(n_splits=self.n_splits, random_state=0, shuffle=True)
        oof_scores = []

        for fold, (train_idx, val_idx) in enumerate(kfold.split(X)):
            print(f"\nFold - {fold}\n")

            x_train, y_train = X.iloc[train_idx], y.iloc[train_idx]
            x_val, y_val = X.iloc[val_idx], y.iloc[val_idx]
            
            x_train, x_val = get_quantile_transform(x_train, x_val)
            x_train, x_val = get_transform(x_train, x_val, scaler_name)
            
            model = base_model(486, 1, encoder)
            model.compile(
                tf.keras.optimizers.Adam(learning_rate=0.005),
                loss=root_mean_squared_per_error
            )
        
            cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(self.model_path, f"nnse_{fold}.h5"),
                                                             save_weights_only=True,
                                                             verbose=0)
            
            model.fit([x_train, x_train.drop(["stock_id"], axis=1)],
                      y_train,              
                      batch_size=1024,
                      epochs=200,
                      validation_data=([x_val, x_val.drop(["stock_id"], axis=1)], y_val),
                      callbacks=callback_list+[cp_callback],
                      validation_batch_size=len(y_val),
                      shuffle=True,
                      verbose=1)
            
            fold_preds = model.predict([x_val, x_val.drop(["stock_id"], axis=1)])[:, 0]
            oof_score = rmspe(y_val, fold_preds)
            print(f"\nRMSPE of fold {fold}: {oof_score}")
            
            oof_scores.append(oof_score)
            oof_predictions[val_idx] = fold_preds
            
            del x_train, x_val, y_train, y_val, model, fold_preds
            _ = gc.collect()
        
        print(f"\nOOF Scores: {oof_scores}\n")
        rmspe_score = rmspe(y, oof_predictions)
        print(f"OOF RMSPE: {rmspe_score}")
        
        return y, oof_predictions

# %% [markdown]
# # Train

# %%
if __name__ == "__main__":
    _ = gc.collect()
    
    train_feats = pickle.load(open("../input/dataorvpprocessed/train_df.pkl", "rb"))
    train_feats.fillna(-1, inplace=True)
    reg = TrainFer(n_splits=5, model_path=cfg.paths["dae"], random_state=cfg.random_state) 

    es = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=20,
        verbose=1,
        mode='min',
        restore_best_weights=True)

    plateau = tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.3,
        patience=7,
        verbose=1,
        mode='min')
    
    callback_list = [es, plateau]
    y_targets, oof_preds = reg.train(train_feats.drop(columns=["row_id", "target", "time_id"]), train_feats["target"], callback_list, "mm")
    pickle.dump(y_targets, open("./y_targets_mm.pkl", "wb"))
    pickle.dump(oof_preds, open("./oof_preds_mm.pkl", "wb"))
    pass
# Out:
# [INFO] Loading trained Encoder...
#
# Fold - 0
#
# [INFO] Applying Quantile Transformation...
#   0%|          | 0/487 [00:00<?, ?it/s]
# [INFO] Using mm scaler...
#   0%|          | 0/487 [00:00<?, ?it/s]
# Epoch 1/200
# 336/336 [==============================] - 15s 22ms/step - loss: 281.5131 - val_loss: 10.4635
# Epoch 2/200
# 336/336 [==============================] - 6s 16ms/step - loss: 4.1447 - val_loss: 2.3613
# Epoch 3/200
# 336/336 [==============================] - 5s 16ms/step - loss: 2.3882 - val_loss: 2.0273
# Epoch 4/200
# 336/336 [==============================] - 6s 17ms/step - loss: 2.3014 - val_loss: 2.3971
# Epoch 5/200
# 336/336 [==============================] - 6s 17ms/step - loss: 2.1129 - val_loss: 1.6827
# Epoch 6/200
# 336/336 [==============================] - 6s 16ms/step - loss: 2.1263 - val_loss: 3.2536
# Epoch 7/200
# 336/336 [==============================] - 5s 16ms/step - loss: 2.4740 - val_loss: 2.2142
# Epoch 8/200
# 336/336 [==============================] - 6s 16ms/step - loss: 2.3574 - val_loss: 0.8801
# Epoch 9/200
# 336/336 [==============================] - 5s 16ms/step - loss: 1.7111 - val_loss: 2.2615
# Epoch 10/200
# 336/336 [==============================] - 6s 16ms/step - loss: 2.0565 - val_loss: 1.6597
# Epoch 11/200
# 336/336 [==============================] - 6s 17ms/step - loss: 2.0511 - val_loss: 0.6605
# Epoch 12/200
# 336/336 [==============================] - 6s 16ms/step - loss: 1.4613 - val_loss: 1.7992
# Epoch 13/200
# 336/336 [==============================] - 5s 16ms/step - loss: 1.4461 - val_loss: 1.5580
# Epoch 14/200
# 336/336 [==============================] - 5s 16ms/step - loss: 1.2371 - val_loss: 0.4903
# Epoch 15/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.6957 - val_loss: 0.4200
# Epoch 16/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.8291 - val_loss: 0.7061
# Epoch 17/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.5811 - val_loss: 0.3298
# Epoch 18/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.4803 - val_loss: 0.9797
# Epoch 19/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.5145 - val_loss: 0.3664
# Epoch 20/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.5508 - val_loss: 0.2493
# Epoch 21/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.3543 - val_loss: 0.3352
# Epoch 22/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.3128 - val_loss: 0.4025
# Epoch 23/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.3723 - val_loss: 0.2486
# Epoch 24/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.3069 - val_loss: 0.2820
# Epoch 25/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2943 - val_loss: 0.2525
# Epoch 26/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2989 - val_loss: 0.2831
# Epoch 27/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2979 - val_loss: 0.2468
# Epoch 28/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2933 - val_loss: 0.3347
# Epoch 29/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2988 - val_loss: 0.2712
# Epoch 30/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.3059 - val_loss: 0.2237
# Epoch 31/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2936 - val_loss: 0.3001
# Epoch 32/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.3238 - val_loss: 0.2488
# Epoch 33/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.3217 - val_loss: 0.2728
# Epoch 34/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.2943 - val_loss: 0.2209
# Epoch 35/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.3440 - val_loss: 0.2385
# Epoch 36/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2953 - val_loss: 0.8553
# Epoch 37/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.4158 - val_loss: 0.2209
# Epoch 38/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2949 - val_loss: 0.2247
# Epoch 39/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.3238 - val_loss: 0.3350
# Epoch 40/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.3052 - val_loss: 0.2342
# Epoch 41/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.3046 - val_loss: 0.3085
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.0014999999664723873.
# Epoch 42/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2661 - val_loss: 0.2237
# Epoch 43/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2434 - val_loss: 0.2157
# Epoch 44/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2456 - val_loss: 0.2421
# Epoch 45/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2494 - val_loss: 0.2601
# Epoch 46/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2488 - val_loss: 0.2216
# Epoch 47/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2553 - val_loss: 0.2606
# Epoch 48/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.2618 - val_loss: 0.2315
# Epoch 49/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2479 - val_loss: 0.2351
# Epoch 50/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2508 - val_loss: 0.2444
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 0.00045000000391155477.
# Epoch 51/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2353 - val_loss: 0.2253
# Epoch 52/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2297 - val_loss: 0.2228
# Epoch 53/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2276 - val_loss: 0.2153
# Epoch 54/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.2268 - val_loss: 0.2473
# Epoch 55/200
# 336/336 [==============================] - 6s 18ms/step - loss: 0.2294 - val_loss: 0.2180
# Epoch 56/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2237 - val_loss: 0.2144
# Epoch 57/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2244 - val_loss: 0.2317
# Epoch 58/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2279 - val_loss: 0.2178
# Epoch 59/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2222 - val_loss: 0.2314
# Epoch 60/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2230 - val_loss: 0.2308
# Epoch 61/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2251 - val_loss: 0.2135
# Epoch 62/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2217 - val_loss: 0.2139
# Epoch 63/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2217 - val_loss: 0.2311
# Epoch 64/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2208 - val_loss: 0.2152
# Epoch 65/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.2198 - val_loss: 0.2185
# Epoch 66/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2200 - val_loss: 0.2193
# Epoch 67/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2207 - val_loss: 0.2170
# Epoch 68/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2157 - val_loss: 0.2128
# Epoch 69/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.2145 - val_loss: 0.2186
# Epoch 70/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2155 - val_loss: 0.2147
# Epoch 71/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2147 - val_loss: 0.2368
# Epoch 72/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.2167 - val_loss: 0.2129
# Epoch 73/200
# 336/336 [==============================] - 6s 18ms/step - loss: 0.2162 - val_loss: 0.2443
# Epoch 74/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2103 - val_loss: 0.2221
# Epoch 75/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.2120 - val_loss: 0.2187
#
# Epoch 00075: ReduceLROnPlateau reducing learning rate to 0.00013499999768100678.
# Epoch 76/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.1991 - val_loss: 0.2182
# Epoch 77/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.1963 - val_loss: 0.2194
# Epoch 78/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.1942 - val_loss: 0.2157
# Epoch 79/200
# 336/336 [==============================] - 6s 18ms/step - loss: 0.1942 - val_loss: 0.2147
# Epoch 80/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.1936 - val_loss: 0.2258
# Epoch 81/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.1947 - val_loss: 0.2223
# Epoch 82/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.1925 - val_loss: 0.2220
#
# Epoch 00082: ReduceLROnPlateau reducing learning rate to 4.049999843118712e-05.
# Epoch 83/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.1889 - val_loss: 0.2181
# Epoch 84/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.1874 - val_loss: 0.2194
# Epoch 85/200
# 336/336 [==============================] - 6s 18ms/step - loss: 0.1873 - val_loss: 0.2202
# Epoch 86/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.1876 - val_loss: 0.2209
# Epoch 87/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.1869 - val_loss: 0.2199
# Epoch 88/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.1874 - val_loss: 0.2186
# Restoring model weights from the end of the best epoch.
# Epoch 00088: early stopping
#
# RMSPE of fold 0: 0.21282951937343586
#
# Fold - 1
#
# [INFO] Applying Quantile Transformation...
#   0%|          | 0/487 [00:00<?, ?it/s]
# [INFO] Using mm scaler...
#   0%|          | 0/487 [00:00<?, ?it/s]
# Epoch 1/200
# 336/336 [==============================] - 8s 21ms/step - loss: 246.4365 - val_loss: 3.7835
# Epoch 2/200
# 336/336 [==============================] - 5s 16ms/step - loss: 3.6865 - val_loss: 2.8702
# Epoch 3/200
# 336/336 [==============================] - 5s 16ms/step - loss: 3.8528 - val_loss: 4.4753
# Epoch 4/200
# 336/336 [==============================] - 5s 16ms/step - loss: 3.8546 - val_loss: 2.7055
# Epoch 5/200
# 336/336 [==============================] - 6s 17ms/step - loss: 5.2906 - val_loss: 0.8509
# Epoch 6/200
# 336/336 [==============================] - 6s 16ms/step - loss: 1.9333 - val_loss: 1.3211
# Epoch 7/200
# 336/336 [==============================] - 6s 17ms/step - loss: 3.4155 - val_loss: 0.8418
# Epoch 8/200
# 336/336 [==============================] - 5s 16ms/step - loss: 2.7732 - val_loss: 1.8042
# Epoch 9/200
# 336/336 [==============================] - 6s 16ms/step - loss: 2.2540 - val_loss: 4.2788
# Epoch 10/200
# 336/336 [==============================] - 5s 16ms/step - loss: 1.8936 - val_loss: 0.9676
# Epoch 11/200
# 336/336 [==============================] - 6s 18ms/step - loss: 1.1596 - val_loss: 0.8654
# Epoch 12/200
# 336/336 [==============================] - 5s 16ms/step - loss: 1.2093 - val_loss: 0.5793
# Epoch 13/200
# 336/336 [==============================] - 6s 17ms/step - loss: 1.0901 - val_loss: 0.9661
# Epoch 14/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.8123 - val_loss: 0.3842
# Epoch 15/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.4603 - val_loss: 0.8906
# Epoch 16/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.6022 - val_loss: 0.5790
# Epoch 17/200
# 336/336 [==============================] - 6s 18ms/step - loss: 0.4018 - val_loss: 0.3540
# Epoch 18/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.3670 - val_loss: 0.4042
# Epoch 19/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.3649 - val_loss: 0.3754
# Epoch 20/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.3661 - val_loss: 0.3560
# Epoch 21/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.3874 - val_loss: 0.3493
# Epoch 22/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.3167 - val_loss: 0.3456
# Epoch 23/200
# 336/336 [==============================] - 6s 18ms/step - loss: 0.3251 - val_loss: 0.4052
# Epoch 24/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.3096 - val_loss: 0.2890
# Epoch 25/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2887 - val_loss: 0.2807
# Epoch 26/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.3144 - val_loss: 0.2546
# Epoch 27/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2971 - val_loss: 0.3315
# Epoch 28/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2981 - val_loss: 0.2464
# Epoch 29/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2731 - val_loss: 0.2355
# Epoch 30/200
# 336/336 [==============================] - 6s 18ms/step - loss: 0.2817 - val_loss: 0.3659
# Epoch 31/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.3309 - val_loss: 0.2257
# Epoch 32/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.3040 - val_loss: 0.2472
# Epoch 33/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.3081 - val_loss: 0.2986
# Epoch 34/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.3661 - val_loss: 0.3112
# Epoch 35/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.3653 - val_loss: 0.2594
# Epoch 36/200
# 336/336 [==============================] - 6s 19ms/step - loss: 0.3083 - val_loss: 0.2706
# Epoch 37/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.3561 - val_loss: 0.2885
# Epoch 38/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.3132 - val_loss: 0.2543
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.0014999999664723873.
# Epoch 39/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2553 - val_loss: 0.2380
# Epoch 40/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2564 - val_loss: 0.2202
# Epoch 41/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2511 - val_loss: 0.2215
# Epoch 42/200
# 336/336 [==============================] - 6s 18ms/step - loss: 0.2490 - val_loss: 0.2758
# Epoch 43/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2537 - val_loss: 0.2570
# Epoch 44/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2537 - val_loss: 0.2344
# Epoch 45/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2509 - val_loss: 0.2277
# Epoch 46/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2498 - val_loss: 0.2643
# Epoch 47/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.2516 - val_loss: 0.2642
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.00045000000391155477.
# Epoch 48/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2345 - val_loss: 0.2201
# Epoch 49/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2328 - val_loss: 0.2262
# Epoch 50/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2310 - val_loss: 0.2158
# Epoch 51/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2282 - val_loss: 0.2342
# Epoch 52/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2297 - val_loss: 0.2396
# Epoch 53/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2329 - val_loss: 0.2218
# Epoch 54/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.2281 - val_loss: 0.2210
# Epoch 55/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2302 - val_loss: 0.2306
# Epoch 56/200
# 336/336 [==============================] - 6s 18ms/step - loss: 0.2275 - val_loss: 0.2357
# Epoch 57/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2305 - val_loss: 0.2311
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 0.00013499999768100678.
# Epoch 58/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.2215 - val_loss: 0.2144
# Epoch 59/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2189 - val_loss: 0.2148
# Epoch 60/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.2189 - val_loss: 0.2129
# Epoch 61/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2172 - val_loss: 0.2212
# Epoch 62/200
# 336/336 [==============================] - 6s 18ms/step - loss: 0.2193 - val_loss: 0.2138
# Epoch 63/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2169 - val_loss: 0.2157
# Epoch 64/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.2167 - val_loss: 0.2119
# Epoch 65/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2157 - val_loss: 0.2178
# Epoch 66/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.2137 - val_loss: 0.2190
# Epoch 67/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2137 - val_loss: 0.2156
# Epoch 68/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2130 - val_loss: 0.2141
# Epoch 69/200
# 336/336 [==============================] - 6s 18ms/step - loss: 0.2174 - val_loss: 0.2280
# Epoch 70/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2114 - val_loss: 0.2146
# Epoch 71/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2118 - val_loss: 0.2238
#
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 4.049999843118712e-05.
# Epoch 72/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.2084 - val_loss: 0.2137
# Epoch 73/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2071 - val_loss: 0.2146
# Epoch 74/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2060 - val_loss: 0.2151
# Epoch 75/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2062 - val_loss: 0.2202
# Epoch 76/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2055 - val_loss: 0.2159
# Epoch 77/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2047 - val_loss: 0.2156
# Epoch 78/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2045 - val_loss: 0.2150
#
# Epoch 00078: ReduceLROnPlateau reducing learning rate to 1.2149999747634865e-05.
# Epoch 79/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2032 - val_loss: 0.2172
# Epoch 80/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2027 - val_loss: 0.2155
# Epoch 81/200
# 336/336 [==============================] - 6s 19ms/step - loss: 0.2027 - val_loss: 0.2154
# Epoch 82/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2032 - val_loss: 0.2163
# Epoch 83/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2024 - val_loss: 0.2158
# Epoch 84/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2032 - val_loss: 0.2157
# Restoring model weights from the end of the best epoch.
# Epoch 00084: early stopping
#
# RMSPE of fold 1: 0.21193850544443446
#
# Fold - 2
#
# [INFO] Applying Quantile Transformation...
#   0%|          | 0/487 [00:00<?, ?it/s]
# [INFO] Using mm scaler...
#   0%|          | 0/487 [00:00<?, ?it/s]
# Epoch 1/200
# 336/336 [==============================] - 8s 21ms/step - loss: 252.7574 - val_loss: 3.5275
# Epoch 2/200
# 336/336 [==============================] - 5s 16ms/step - loss: 4.0208 - val_loss: 2.3401
# Epoch 3/200
# 336/336 [==============================] - 5s 16ms/step - loss: 2.6374 - val_loss: 3.6120
# Epoch 4/200
# 336/336 [==============================] - 7s 19ms/step - loss: 2.2914 - val_loss: 2.6950
# Epoch 5/200
# 336/336 [==============================] - 6s 18ms/step - loss: 3.3661 - val_loss: 6.9957
# Epoch 6/200
# 336/336 [==============================] - 6s 17ms/step - loss: 2.5848 - val_loss: 2.9700
# Epoch 7/200
# 336/336 [==============================] - 5s 16ms/step - loss: 2.6535 - val_loss: 1.9552
# Epoch 8/200
# 336/336 [==============================] - 6s 17ms/step - loss: 3.1363 - val_loss: 2.5376
# Epoch 9/200
# 336/336 [==============================] - 5s 16ms/step - loss: 2.1554 - val_loss: 2.3283
# Epoch 10/200
# 336/336 [==============================] - 6s 17ms/step - loss: 1.8547 - val_loss: 2.7944
# Epoch 11/200
# 336/336 [==============================] - 5s 16ms/step - loss: 2.1844 - val_loss: 1.9211
# Epoch 12/200
# 336/336 [==============================] - 6s 17ms/step - loss: 1.7862 - val_loss: 1.0640
# Epoch 13/200
# 336/336 [==============================] - 6s 16ms/step - loss: 1.2850 - val_loss: 3.3342
# Epoch 14/200
# 336/336 [==============================] - 6s 17ms/step - loss: 1.5109 - val_loss: 0.7616
# Epoch 15/200
# 336/336 [==============================] - 5s 16ms/step - loss: 1.1543 - val_loss: 0.4409
# Epoch 16/200
# 336/336 [==============================] - 6s 19ms/step - loss: 0.6125 - val_loss: 0.8242
# Epoch 17/200
# 336/336 [==============================] - 6s 18ms/step - loss: 0.6371 - val_loss: 0.3240
# Epoch 18/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.6154 - val_loss: 0.3348
# Epoch 19/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.3947 - val_loss: 0.4248
# Epoch 20/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.3683 - val_loss: 0.3043
# Epoch 21/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.3448 - val_loss: 0.7372
# Epoch 22/200
# 336/336 [==============================] - 6s 18ms/step - loss: 0.3633 - val_loss: 0.3279
# Epoch 23/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.3265 - val_loss: 0.2456
# Epoch 24/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.3146 - val_loss: 0.2700
# Epoch 25/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.3096 - val_loss: 0.2262
# Epoch 26/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.3011 - val_loss: 0.3348
# Epoch 27/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.3168 - val_loss: 0.3787
# Epoch 28/200
# 336/336 [==============================] - 6s 19ms/step - loss: 0.3254 - val_loss: 0.3014
# Epoch 29/200
# 336/336 [==============================] - 6s 19ms/step - loss: 0.2964 - val_loss: 0.3081
# Epoch 30/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.3139 - val_loss: 0.4197
# Epoch 31/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.3151 - val_loss: 0.3245
# Epoch 32/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.3480 - val_loss: 0.3090
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0014999999664723873.
# Epoch 33/200
# 336/336 [==============================] - 6s 18ms/step - loss: 0.2573 - val_loss: 0.2201
# Epoch 34/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2495 - val_loss: 0.2253
# Epoch 35/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2485 - val_loss: 0.3141
# Epoch 36/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2565 - val_loss: 0.2242
# Epoch 37/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.2525 - val_loss: 0.2422
# Epoch 38/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2565 - val_loss: 0.2389
# Epoch 39/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2631 - val_loss: 0.2447
# Epoch 40/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2494 - val_loss: 0.2473
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.00045000000391155477.
# Epoch 41/200
# 336/336 [==============================] - 6s 19ms/step - loss: 0.2428 - val_loss: 0.2261
# Epoch 42/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2384 - val_loss: 0.2310
# Epoch 43/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2367 - val_loss: 0.2272
# Epoch 44/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.2356 - val_loss: 0.2344
# Epoch 45/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2371 - val_loss: 0.2190
# Epoch 46/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.2334 - val_loss: 0.2319
# Epoch 47/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.2341 - val_loss: 0.2207
# Epoch 48/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.2351 - val_loss: 0.2344
# Epoch 49/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.2325 - val_loss: 0.2320
# Epoch 50/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2349 - val_loss: 0.2306
# Epoch 51/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.2381 - val_loss: 0.2190
# Epoch 52/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.2333 - val_loss: 0.2539
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 0.00013499999768100678.
# Epoch 53/200
# 336/336 [==============================] - 6s 18ms/step - loss: 0.2257 - val_loss: 0.2257
# Epoch 54/200
# 336/336 [==============================] - 6s 19ms/step - loss: 0.2237 - val_loss: 0.2234
# Epoch 55/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2259 - val_loss: 0.2184
# Epoch 56/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2239 - val_loss: 0.2195
# Epoch 57/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2233 - val_loss: 0.2165
# Epoch 58/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2206 - val_loss: 0.2197
# Epoch 59/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2219 - val_loss: 0.2173
# Epoch 60/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2219 - val_loss: 0.2303
# Epoch 61/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2211 - val_loss: 0.2262
# Epoch 62/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2217 - val_loss: 0.2163
# Epoch 63/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2194 - val_loss: 0.2252
# Epoch 64/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.2191 - val_loss: 0.2205
# Epoch 65/200
# 336/336 [==============================] - 6s 18ms/step - loss: 0.2192 - val_loss: 0.2206
# Epoch 66/200
# 336/336 [==============================] - 6s 19ms/step - loss: 0.2192 - val_loss: 0.2242
# Epoch 67/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2196 - val_loss: 0.2183
# Epoch 68/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.2163 - val_loss: 0.2176
# Epoch 69/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2180 - val_loss: 0.2224
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 4.049999843118712e-05.
# Epoch 70/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2133 - val_loss: 0.2173
# Epoch 71/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.2127 - val_loss: 0.2208
# Epoch 72/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2117 - val_loss: 0.2188
# Epoch 73/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2122 - val_loss: 0.2178
# Epoch 74/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2127 - val_loss: 0.2199
# Epoch 75/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2120 - val_loss: 0.2196
# Epoch 76/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2109 - val_loss: 0.2186
#
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 1.2149999747634865e-05.
# Epoch 77/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.2101 - val_loss: 0.2195
# Epoch 78/200
# 336/336 [==============================] - 7s 20ms/step - loss: 0.2096 - val_loss: 0.2193
# Epoch 79/200
# 336/336 [==============================] - 6s 19ms/step - loss: 0.2094 - val_loss: 0.2192
# Epoch 80/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2090 - val_loss: 0.2185
# Epoch 81/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2093 - val_loss: 0.2192
# Epoch 82/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2092 - val_loss: 0.2199
# Restoring model weights from the end of the best epoch.
# Epoch 00082: early stopping
#
# RMSPE of fold 2: 0.21630342780264591
#
# Fold - 3
#
# [INFO] Applying Quantile Transformation...
#   0%|          | 0/487 [00:00<?, ?it/s]
# [INFO] Using mm scaler...
#   0%|          | 0/487 [00:00<?, ?it/s]
# Epoch 1/200
# 336/336 [==============================] - 8s 20ms/step - loss: 246.7580 - val_loss: 2.0389
# Epoch 2/200
# 336/336 [==============================] - 6s 17ms/step - loss: 3.0707 - val_loss: 1.9687
# Epoch 3/200
# 336/336 [==============================] - 5s 16ms/step - loss: 2.9213 - val_loss: 2.3876
# Epoch 4/200
# 336/336 [==============================] - 6s 17ms/step - loss: 3.2671 - val_loss: 4.5273
# Epoch 5/200
# 336/336 [==============================] - 6s 18ms/step - loss: 3.0547 - val_loss: 2.6704
# Epoch 6/200
# 336/336 [==============================] - 6s 19ms/step - loss: 2.7693 - val_loss: 4.0426
# Epoch 7/200
# 336/336 [==============================] - 6s 17ms/step - loss: 3.0386 - val_loss: 1.3124
# Epoch 8/200
# 336/336 [==============================] - 6s 17ms/step - loss: 2.9132 - val_loss: 1.1105
# Epoch 9/200
# 336/336 [==============================] - 5s 16ms/step - loss: 1.5492 - val_loss: 0.9726
# Epoch 10/200
# 336/336 [==============================] - 6s 17ms/step - loss: 1.5489 - val_loss: 1.5318
# Epoch 11/200
# 336/336 [==============================] - 5s 16ms/step - loss: 1.9065 - val_loss: 2.3536
# Epoch 12/200
# 336/336 [==============================] - 6s 17ms/step - loss: 1.7619 - val_loss: 0.8542
# Epoch 13/200
# 336/336 [==============================] - 6s 16ms/step - loss: 1.5340 - val_loss: 0.8269
# Epoch 14/200
# 336/336 [==============================] - 6s 17ms/step - loss: 1.3871 - val_loss: 1.5258
# Epoch 15/200
# 336/336 [==============================] - 6s 16ms/step - loss: 1.1027 - val_loss: 1.5972
# Epoch 16/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.8536 - val_loss: 1.0694
# Epoch 17/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.6353 - val_loss: 1.0942
# Epoch 18/200
# 336/336 [==============================] - 6s 18ms/step - loss: 0.6666 - val_loss: 0.4954
# Epoch 19/200
# 336/336 [==============================] - 7s 20ms/step - loss: 0.4013 - val_loss: 0.4462
# Epoch 20/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.3741 - val_loss: 0.4341
# Epoch 21/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.3735 - val_loss: 0.3065
# Epoch 22/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.3431 - val_loss: 0.2408
# Epoch 23/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.3035 - val_loss: 1.3034
# Epoch 24/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2926 - val_loss: 0.4367
# Epoch 25/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.3062 - val_loss: 0.2921
# Epoch 26/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2941 - val_loss: 0.2677
# Epoch 27/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2845 - val_loss: 0.2430
# Epoch 28/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.3215 - val_loss: 0.2784
# Epoch 29/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2969 - val_loss: 0.4682
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0014999999664723873.
# Epoch 30/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2730 - val_loss: 0.2261
# Epoch 31/200
# 336/336 [==============================] - 7s 19ms/step - loss: 0.2531 - val_loss: 0.2230
# Epoch 32/200
# 336/336 [==============================] - 6s 18ms/step - loss: 0.2500 - val_loss: 0.2553
# Epoch 33/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.2593 - val_loss: 0.2870
# Epoch 34/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.2560 - val_loss: 0.2254
# Epoch 35/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2598 - val_loss: 0.2363
# Epoch 36/200
# 336/336 [==============================] - 6s 18ms/step - loss: 0.2529 - val_loss: 0.2497
# Epoch 37/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2531 - val_loss: 0.3059
# Epoch 38/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2646 - val_loss: 0.2784
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.00045000000391155477.
# Epoch 39/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2373 - val_loss: 0.2389
# Epoch 40/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2362 - val_loss: 0.2161
# Epoch 41/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2359 - val_loss: 0.2328
# Epoch 42/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2377 - val_loss: 0.2247
# Epoch 43/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2372 - val_loss: 0.2240
# Epoch 44/200
# 336/336 [==============================] - 6s 19ms/step - loss: 0.2369 - val_loss: 0.2188
# Epoch 45/200
# 336/336 [==============================] - 6s 18ms/step - loss: 0.2347 - val_loss: 0.2491
# Epoch 46/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2362 - val_loss: 0.2230
# Epoch 47/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2349 - val_loss: 0.2610
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.00013499999768100678.
# Epoch 48/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.2281 - val_loss: 0.2170
# Epoch 49/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2262 - val_loss: 0.2344
# Epoch 50/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2263 - val_loss: 0.2178
# Epoch 51/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2274 - val_loss: 0.2231
# Epoch 52/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2258 - val_loss: 0.2163
# Epoch 53/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2247 - val_loss: 0.2174
# Epoch 54/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2259 - val_loss: 0.2199
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 4.049999843118712e-05.
# Epoch 55/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2220 - val_loss: 0.2148
# Epoch 56/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2214 - val_loss: 0.2169
# Epoch 57/200
# 336/336 [==============================] - 6s 18ms/step - loss: 0.2210 - val_loss: 0.2159
# Epoch 58/200
# 336/336 [==============================] - 6s 19ms/step - loss: 0.2213 - val_loss: 0.2154
# Epoch 59/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2211 - val_loss: 0.2163
# Epoch 60/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2217 - val_loss: 0.2148
# Epoch 61/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2205 - val_loss: 0.2148
# Epoch 62/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2202 - val_loss: 0.2212
#
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 1.2149999747634865e-05.
# Epoch 63/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2202 - val_loss: 0.2156
# Epoch 64/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2189 - val_loss: 0.2160
# Epoch 65/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2191 - val_loss: 0.2156
# Epoch 66/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2193 - val_loss: 0.2149
# Epoch 67/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2191 - val_loss: 0.2159
# Epoch 68/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2193 - val_loss: 0.2155
# Epoch 69/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2197 - val_loss: 0.2177
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 3.6449999242904594e-06.
# Epoch 70/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2195 - val_loss: 0.2164
# Epoch 71/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2200 - val_loss: 0.2157
# Epoch 72/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2185 - val_loss: 0.2158
# Epoch 73/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2183 - val_loss: 0.2155
# Epoch 74/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2188 - val_loss: 0.2153
# Epoch 75/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2183 - val_loss: 0.2154
# Epoch 76/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2190 - val_loss: 0.2150
#
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 1.0934999636447174e-06.
# Epoch 77/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2187 - val_loss: 0.2157
# Epoch 78/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2183 - val_loss: 0.2156
# Epoch 79/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2183 - val_loss: 0.2155
# Epoch 80/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2183 - val_loss: 0.2156
# Restoring model weights from the end of the best epoch.
# Epoch 00080: early stopping
#
# RMSPE of fold 3: 0.21480358242615646
#
# Fold - 4
#
# [INFO] Applying Quantile Transformation...
#   0%|          | 0/487 [00:00<?, ?it/s]
# [INFO] Using mm scaler...
#   0%|          | 0/487 [00:00<?, ?it/s]
# Epoch 1/200
# 336/336 [==============================] - 8s 21ms/step - loss: 266.2920 - val_loss: 3.3032
# Epoch 2/200
# 336/336 [==============================] - 6s 17ms/step - loss: 3.6050 - val_loss: 2.3471
# Epoch 3/200
# 336/336 [==============================] - 6s 17ms/step - loss: 2.0224 - val_loss: 1.1176
# Epoch 4/200
# 336/336 [==============================] - 5s 16ms/step - loss: 1.8060 - val_loss: 4.8525
# Epoch 5/200
# 336/336 [==============================] - 6s 17ms/step - loss: 2.6319 - val_loss: 1.0782
# Epoch 6/200
# 336/336 [==============================] - 5s 16ms/step - loss: 2.3434 - val_loss: 1.9736
# Epoch 7/200
# 336/336 [==============================] - 6s 17ms/step - loss: 1.8504 - val_loss: 1.5157
# Epoch 8/200
# 336/336 [==============================] - 5s 16ms/step - loss: 1.5861 - val_loss: 1.1292
# Epoch 9/200
# 336/336 [==============================] - 6s 17ms/step - loss: 1.8334 - val_loss: 2.0944
# Epoch 10/200
# 336/336 [==============================] - 5s 16ms/step - loss: 1.8314 - val_loss: 1.5966
# Epoch 11/200
# 336/336 [==============================] - 6s 17ms/step - loss: 1.6782 - val_loss: 6.3445
# Epoch 12/200
# 336/336 [==============================] - 5s 16ms/step - loss: 1.9143 - val_loss: 0.6934
# Epoch 13/200
# 336/336 [==============================] - 6s 18ms/step - loss: 1.1647 - val_loss: 1.0604
# Epoch 14/200
# 336/336 [==============================] - 5s 16ms/step - loss: 1.3858 - val_loss: 1.4319
# Epoch 15/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.9897 - val_loss: 0.8130
# Epoch 16/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.6826 - val_loss: 1.1950
# Epoch 17/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.7939 - val_loss: 0.8552
# Epoch 18/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.5843 - val_loss: 0.8149
# Epoch 19/200
# 336/336 [==============================] - 6s 18ms/step - loss: 0.4526 - val_loss: 0.4917
# Epoch 20/200
# 336/336 [==============================] - 6s 19ms/step - loss: 0.4357 - val_loss: 0.3546
# Epoch 21/200
# 336/336 [==============================] - 6s 18ms/step - loss: 0.3249 - val_loss: 0.2885
# Epoch 22/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.3311 - val_loss: 0.3492
# Epoch 23/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2898 - val_loss: 0.3731
# Epoch 24/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.3020 - val_loss: 0.3345
# Epoch 25/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.3048 - val_loss: 0.4443
# Epoch 26/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.3224 - val_loss: 0.4272
# Epoch 27/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2937 - val_loss: 0.2538
# Epoch 28/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2903 - val_loss: 0.2892
# Epoch 29/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.3158 - val_loss: 0.4741
# Epoch 30/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.4149 - val_loss: 0.3193
# Epoch 31/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.3322 - val_loss: 0.2409
# Epoch 32/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.3001 - val_loss: 0.5353
# Epoch 33/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.3266 - val_loss: 0.2499
# Epoch 34/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2927 - val_loss: 0.4697
# Epoch 35/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.3039 - val_loss: 0.2388
# Epoch 36/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.3054 - val_loss: 0.3385
# Epoch 37/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.3340 - val_loss: 0.3335
# Epoch 38/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.3164 - val_loss: 0.2983
# Epoch 39/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.3297 - val_loss: 0.3348
# Epoch 40/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.3129 - val_loss: 0.3655
# Epoch 41/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.3218 - val_loss: 0.2506
# Epoch 42/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.3338 - val_loss: 0.2803
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 0.0014999999664723873.
# Epoch 43/200
# 336/336 [==============================] - 6s 18ms/step - loss: 0.2515 - val_loss: 0.2335
# Epoch 44/200
# 336/336 [==============================] - 6s 18ms/step - loss: 0.2469 - val_loss: 0.2298
# Epoch 45/200
# 336/336 [==============================] - 6s 19ms/step - loss: 0.2468 - val_loss: 0.2538
# Epoch 46/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2474 - val_loss: 0.2318
# Epoch 47/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2487 - val_loss: 0.2981
# Epoch 48/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2620 - val_loss: 0.2637
# Epoch 49/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2504 - val_loss: 0.2235
# Epoch 50/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2581 - val_loss: 0.2325
# Epoch 51/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2495 - val_loss: 0.2385
# Epoch 52/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2427 - val_loss: 0.2292
# Epoch 53/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2461 - val_loss: 0.2371
# Epoch 54/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2572 - val_loss: 0.2297
# Epoch 55/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2442 - val_loss: 0.2603
# Epoch 56/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2550 - val_loss: 0.2473
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 0.00045000000391155477.
# Epoch 57/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.2269 - val_loss: 0.2205
# Epoch 58/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2243 - val_loss: 0.2246
# Epoch 59/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.2236 - val_loss: 0.2312
# Epoch 60/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2226 - val_loss: 0.2448
# Epoch 61/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.2264 - val_loss: 0.2226
# Epoch 62/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2217 - val_loss: 0.2379
# Epoch 63/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2210 - val_loss: 0.2369
# Epoch 64/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2194 - val_loss: 0.2232
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 0.00013499999768100678.
# Epoch 65/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2133 - val_loss: 0.2206
# Epoch 66/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2108 - val_loss: 0.2329
# Epoch 67/200
# 336/336 [==============================] - 6s 18ms/step - loss: 0.2119 - val_loss: 0.2231
# Epoch 68/200
# 336/336 [==============================] - 6s 18ms/step - loss: 0.2098 - val_loss: 0.2208
# Epoch 69/200
# 336/336 [==============================] - 7s 20ms/step - loss: 0.2095 - val_loss: 0.2264
# Epoch 70/200
# 336/336 [==============================] - 6s 18ms/step - loss: 0.2093 - val_loss: 0.2258
# Epoch 71/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2077 - val_loss: 0.2238
#
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 4.049999843118712e-05.
# Epoch 72/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2046 - val_loss: 0.2222
# Epoch 73/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2052 - val_loss: 0.2205
# Epoch 74/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2037 - val_loss: 0.2208
# Epoch 75/200
# 336/336 [==============================] - 6s 17ms/step - loss: 0.2042 - val_loss: 0.2212
# Epoch 76/200
# 336/336 [==============================] - 6s 16ms/step - loss: 0.2045 - val_loss: 0.2216
# Epoch 77/200
# 336/336 [==============================] - 5s 16ms/step - loss: 0.2036 - val_loss: 0.2245
# Restoring model weights from the end of the best epoch.
# Epoch 00077: early stopping
#
# RMSPE of fold 4: 0.22045921302979232
#
# OOF Scores: [0.21282951937343586, 0.21193850544443446, 0.21630342780264591, 0.21480358242615646, 0.22045921302979232]
#
# OOF RMSPE: 0.21528786401933184

# %% [markdown]
# EOF
